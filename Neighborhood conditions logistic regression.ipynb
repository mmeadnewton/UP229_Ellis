# %% [markdown]
# Running a logistic regression on the prepared dataset

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import statsmodels.api as sm
from statsmodels.discrete.discrete_model import Probit

# %%
parcelsjoindf4=pd.read_csv('/Users/alexanderferrer/Documents/GitHub/UP229_Ellis/parcels_finaldf.csv')
# Out:
# /Applications/anaconda3/envs/UP299/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
summarystatdf=parcelsjoindf4[['units_total','sqft_total','yearbuilt_avg',
                       'median_income_2019','median_rent_2019','median_value_2019','part_black_2019',
                       'part_latx_2019', 'part_white_2019', 'part_female_head_2019', 'part_hh_kids_2019',
                       'part_rented_2019', 'part_unemployed_2019', 'part_poverty_2019', 'part_vacant_2019',
                       'part_college_2019','median_income_2014','median_rent_2014','median_value_2014','part_black_2014',
                       'part_latx_2014', 'part_white_2014', 'part_female_head_2014', 'part_hh_kids_2014',
                        'part_rented_2014', 'part_unemployed_2014', 'part_poverty_2014', 'part_vacant_2014',
                       'part_college_2014','change_rent_14_19', 'change_value_14_19', 'change_part_rented_14_19',
                       'change_part_white_14_19', 'change_part_black_14_19', 'change_part_latx_14_19',
                       'change_part_college_14_19', 'change_part_unemployed_14_19', 'change_part_hh_kids_14_19',
                       'change_part_female_head_14_19', 'change_part_poverty_14_19', 'change_part_vacant_14_19',
                       'dist_to_nearest_highrenttract', 'dist_to_nearest_highchangetract','pctbuilt','pctsold' ]].agg(["count","mean","std"])
summarystatdf
# Out:
#          units_total     sqft_total  yearbuilt_avg  median_income_2019  \
# count  100140.000000  100140.000000  100140.000000       100140.000000
# mean        6.232594    5120.825335    1937.454484        59434.744357
# std        15.753543   13646.175242      19.017924        26459.086623
#
#        median_rent_2019  median_value_2019  part_black_2019  part_latx_2019  \
# count     100140.000000      100140.000000    100140.000000   100140.000000
# mean        1429.465289      679136.409452        10.822712       53.120573
# std          377.260626      335927.978379        13.787810       27.802960
#
#        part_white_2019  part_female_head_2019  ...  change_part_college_14_19  \
# count    100140.000000          100140.000000  ...              100140.000000
# mean         24.116878              17.752176  ...                  -0.752131
# std          25.656253               5.510955  ...                   6.147824
#
#        change_part_unemployed_14_19  change_part_hh_kids_14_19  \
# count                 100140.000000              100140.000000
# mean                      -5.665440                  -3.821015
# std                        4.772338                   7.126743
#
#        change_part_female_head_14_19  change_part_poverty_14_19  \
# count                  100140.000000              100140.000000
# mean                        5.982941                  -8.418742
# std                         5.787951                  11.844969
#
#        change_part_vacant_14_19  dist_to_nearest_highrenttract  \
# count             100140.000000                  100140.000000
# mean                   0.120306                    1775.176472
# std                    5.028011                    1880.241243
#
#        dist_to_nearest_highchangetract       pctbuilt        pctsold
# count                    100140.000000  100140.000000  100140.000000
# mean                        804.077293       1.158114      20.426186
# std                         895.771115       1.949679       4.211663
#
# [3 rows x 45 columns]

# %%
summarystatdf.to_csv('/Users/alexanderferrer/Documents/GitHub/UP229_Ellis/summarystatdf.csv')

# %%
data=parcelsjoindf4[['units_total','sqft_total','yearbuilt_avg',
                    'median_income_2014','median_rent_2014','median_value_2014','part_black_2014',
                    'part_latx_2014', 'part_white_2014', 'part_female_head_2014', 'part_hh_kids_2014',
                    'part_rented_2014', 'part_unemployed_2014', 'part_poverty_2014', 'part_vacant_2014',
                    'part_college_2014','dist_to_nearest_highrenttract', 'dist_to_nearest_highchangetract',
                     'ellis_status']]

data = data.drop(data.columns[0], axis = 1)

Y =data['ellis_status']
X =data.drop(['ellis_status'],1)
X = sm.add_constant(X)
model = Probit(Y, X.astype(float))
probit_model = model.fit()
print(probit_model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.057216
#          Iterations 10
#                           Probit Regression Results
# ==============================================================================
# Dep. Variable:           ellis_status   No. Observations:               100140
# Model:                         Probit   Df Residuals:                   100122
# Method:                           MLE   Df Model:                           17
# Date:                Thu, 10 Jun 2021   Pseudo R-squ.:                 0.05324
# Time:                        20:53:13   Log-Likelihood:                -5729.6
# converged:                       True   LL-Null:                       -6051.8
# Covariance Type:            nonrobust   LLR p-value:                5.544e-126
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                               8.0855      1.441      5.611      0.000       5.261      10.910
# sqft_total                      -3.965e-05   4.38e-06     -9.056      0.000   -4.82e-05   -3.11e-05
# yearbuilt_avg                      -0.0058      0.001     -7.786      0.000      -0.007      -0.004
# median_income_2014               5.298e-06   1.57e-06      3.377      0.001    2.22e-06    8.37e-06
# median_rent_2014                   -0.0001   9.58e-05     -1.257      0.209      -0.000    6.73e-05
# median_value_2014                4.507e-08   1.03e-07      0.439      0.661   -1.56e-07    2.46e-07
# part_black_2014                    -0.0009      0.002     -0.619      0.536      -0.004       0.002
# part_latx_2014                     -0.0054      0.002     -3.565      0.000      -0.008      -0.002
# part_white_2014                    -0.0025      0.001     -1.822      0.068      -0.005       0.000
# part_female_head_2014               0.0124      0.006      2.033      0.042       0.000       0.024
# part_hh_kids_2014                   0.0010      0.002      0.525      0.600      -0.003       0.005
# part_rented_2014                    0.0152      0.001     12.894      0.000       0.013       0.017
# part_unemployed_2014               -0.0081      0.003     -2.382      0.017      -0.015      -0.001
# part_poverty_2014                   0.0007      0.001      0.602      0.547      -0.002       0.003
# part_vacant_2014                    0.0104      0.004      2.963      0.003       0.004       0.017
# part_college_2014                  -0.0009      0.002     -0.355      0.722      -0.006       0.004
# dist_to_nearest_highrenttract   -2.279e-05   1.15e-05     -1.982      0.047   -4.53e-05   -2.51e-07
# dist_to_nearest_highchangetract -4.848e-05    2.1e-05     -2.312      0.021   -8.96e-05   -7.38e-06
# ===================================================================================================

# %%
log_reg = sm.Logit(Y, X).fit()

print(log_reg.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.057159
#          Iterations 11
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           ellis_status   No. Observations:               100140
# Model:                          Logit   Df Residuals:                   100122
# Method:                           MLE   Df Model:                           17
# Date:                Thu, 10 Jun 2021   Pseudo R-squ.:                 0.05419
# Time:                        20:53:14   Log-Likelihood:                -5723.9
# converged:                       True   LL-Null:                       -6051.8
# Covariance Type:            nonrobust   LLR p-value:                1.981e-128
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              19.8810      3.730      5.330      0.000      12.571      27.191
# sqft_total                         -0.0001   1.41e-05     -9.120      0.000      -0.000      -0.000
# yearbuilt_avg                      -0.0137      0.002     -7.154      0.000      -0.018      -0.010
# median_income_2014               1.463e-05   4.07e-06      3.597      0.000    6.66e-06    2.26e-05
# median_rent_2014                   -0.0004      0.000     -1.504      0.133      -0.001       0.000
# median_value_2014                 1.14e-07   2.57e-07      0.444      0.657    -3.9e-07    6.18e-07
# part_black_2014                    -0.0022      0.004     -0.580      0.562      -0.010       0.005
# part_latx_2014                     -0.0143      0.004     -3.755      0.000      -0.022      -0.007
# part_white_2014                    -0.0068      0.003     -2.010      0.044      -0.013      -0.000
# part_female_head_2014               0.0329      0.016      2.100      0.036       0.002       0.064
# part_hh_kids_2014                   0.0030      0.005      0.623      0.533      -0.006       0.012
# part_rented_2014                    0.0417      0.003     13.270      0.000       0.036       0.048
# part_unemployed_2014               -0.0237      0.009     -2.662      0.008      -0.041      -0.006
# part_poverty_2014                   0.0019      0.003      0.614      0.539      -0.004       0.008
# part_vacant_2014                    0.0282      0.009      3.039      0.002       0.010       0.046
# part_college_2014                  -0.0022      0.006     -0.349      0.727      -0.015       0.010
# dist_to_nearest_highrenttract   -6.251e-05    3.1e-05     -2.017      0.044      -0.000   -1.78e-06
# dist_to_nearest_highchangetract    -0.0001   5.68e-05     -2.188      0.029      -0.000   -1.29e-05
# ===================================================================================================

# %%
data1=parcelsjoindf4[['units_total','sqft_total','yearbuilt_avg',
                    'median_income_2019','median_rent_2019','median_value_2019','part_black_2019',
                    'part_latx_2019', 'part_white_2019', 'part_female_head_2019', 'part_hh_kids_2019',
                    'part_rented_2019', 'part_unemployed_2019', 'part_poverty_2019', 'part_vacant_2019',
                    'part_college_2019','change_rent_14_19', 'change_value_14_19', 'change_part_rented_14_19',
                    'change_part_white_14_19', 'change_part_black_14_19', 'change_part_latx_14_19',
                    'change_part_college_14_19', 'change_part_unemployed_14_19', 'change_part_hh_kids_14_19',
                    'change_part_female_head_14_19', 'change_part_poverty_14_19', 'change_part_vacant_14_19',
                    'dist_to_nearest_highrenttract', 'dist_to_nearest_highchangetract','pctbuilt','pctsold','ellis_status']]

data1 = data1.drop(data1.columns[0], axis = 1)

Y1 =data1['ellis_status']
X1 =data1.drop(['ellis_status'],1)
X = sm.add_constant(X)
model = Probit(Y1, X1.astype(float))
probit_model = model.fit()
print(probit_model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.056827
#          Iterations 9
#                           Probit Regression Results
# ==============================================================================
# Dep. Variable:           ellis_status   No. Observations:               100140
# Model:                         Probit   Df Residuals:                   100109
# Method:                           MLE   Df Model:                           30
# Date:                Thu, 10 Jun 2021   Pseudo R-squ.:                 0.05968
# Time:                        20:26:08   Log-Likelihood:                -5690.7
# converged:                       True   LL-Null:                       -6051.8
# Covariance Type:            nonrobust   LLR p-value:                1.079e-132
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# sqft_total                      -4.877e-05   4.41e-06    -11.070      0.000   -5.74e-05   -4.01e-05
# yearbuilt_avg                      -0.0017      0.000    -11.688      0.000      -0.002      -0.001
# median_income_2019               1.248e-06   1.32e-06      0.947      0.344   -1.34e-06    3.83e-06
# median_rent_2019                -9.247e-05   9.37e-05     -0.987      0.324      -0.000    9.12e-05
# median_value_2019                6.616e-08   1.04e-07      0.635      0.525   -1.38e-07     2.7e-07
# part_black_2019                     0.0011      0.002      0.597      0.550      -0.003       0.005
# part_latx_2019                     -0.0037      0.002     -2.205      0.027      -0.007      -0.000
# part_white_2019                    -0.0021      0.001     -1.390      0.164      -0.005       0.001
# part_female_head_2019               0.0141      0.008      1.864      0.062      -0.001       0.029
# part_hh_kids_2019                   0.0046      0.002      2.093      0.036       0.000       0.009
# part_rented_2019                    0.0147      0.001     11.240      0.000       0.012       0.017
# part_unemployed_2019                0.0021      0.005      0.390      0.697      -0.008       0.013
# part_poverty_2019                  -0.0002      0.001     -0.165      0.869      -0.003       0.003
# part_vacant_2019                    0.0228      0.004      5.386      0.000       0.014       0.031
# part_college_2019                  -0.0109      0.003     -3.391      0.001      -0.017      -0.005
# change_rent_14_19                   0.0002      0.000      1.652      0.099   -3.61e-05       0.000
# change_value_14_19              -5.809e-08   1.38e-07     -0.422      0.673   -3.28e-07    2.12e-07
# change_part_rented_14_19           -0.0086      0.002     -3.601      0.000      -0.013      -0.004
# change_part_white_14_19            -0.0070      0.003     -2.295      0.022      -0.013      -0.001
# change_part_black_14_19            -0.0112      0.004     -3.053      0.002      -0.018      -0.004
# change_part_latx_14_19             -0.0083      0.003     -2.879      0.004      -0.014      -0.003
# change_part_college_14_19          -0.0008      0.003     -0.289      0.772      -0.006       0.004
# change_part_unemployed_14_19        0.0053      0.003      1.546      0.122      -0.001       0.012
# change_part_hh_kids_14_19          -0.0030      0.002     -1.368      0.171      -0.007       0.001
# change_part_female_head_14_19      -0.0202      0.006     -3.263      0.001      -0.032      -0.008
# change_part_poverty_14_19           0.0019      0.001      1.411      0.158      -0.001       0.004
# change_part_vacant_14_19           -0.0067      0.004     -1.863      0.062      -0.014       0.000
# dist_to_nearest_highrenttract   -3.074e-05    1.2e-05     -2.558      0.011   -5.43e-05   -7.19e-06
# dist_to_nearest_highchangetract -2.168e-05   2.23e-05     -0.970      0.332   -6.55e-05    2.21e-05
# pctbuilt                            0.0138      0.006      2.426      0.015       0.003       0.025
# pctsold                             0.0114      0.003      3.834      0.000       0.006       0.017
# ===================================================================================================

# %%
log_reg1 = sm.Logit(Y1, X1).fit()

print(log_reg1.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.056741
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           ellis_status   No. Observations:               100140
# Model:                          Logit   Df Residuals:                   100109
# Method:                           MLE   Df Model:                           30
# Date:                Thu, 10 Jun 2021   Pseudo R-squ.:                 0.06110
# Time:                        20:26:09   Log-Likelihood:                -5682.0
# converged:                       True   LL-Null:                       -6051.8
# Covariance Type:            nonrobust   LLR p-value:                2.722e-136
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# sqft_total                         -0.0002   1.43e-05    -11.015      0.000      -0.000      -0.000
# yearbuilt_avg                      -0.0038      0.000     -9.892      0.000      -0.005      -0.003
# median_income_2019               3.718e-06   3.37e-06      1.103      0.270   -2.89e-06    1.03e-05
# median_rent_2019                   -0.0003      0.000     -1.262      0.207      -0.001       0.000
# median_value_2019                2.205e-07   2.58e-07      0.854      0.393   -2.85e-07    7.26e-07
# part_black_2019                     0.0029      0.005      0.614      0.539      -0.006       0.012
# part_latx_2019                     -0.0103      0.004     -2.438      0.015      -0.019      -0.002
# part_white_2019                    -0.0053      0.004     -1.445      0.149      -0.012       0.002
# part_female_head_2019               0.0368      0.020      1.871      0.061      -0.002       0.075
# part_hh_kids_2019                   0.0134      0.006      2.355      0.019       0.002       0.025
# part_rented_2019                    0.0414      0.003     11.817      0.000       0.034       0.048
# part_unemployed_2019                0.0034      0.014      0.246      0.806      -0.024       0.031
# part_poverty_2019                  -0.0008      0.004     -0.197      0.844      -0.008       0.007
# part_vacant_2019                    0.0577      0.011      5.321      0.000       0.036       0.079
# part_college_2019                  -0.0279      0.008     -3.378      0.001      -0.044      -0.012
# change_rent_14_19                   0.0006      0.000      1.859      0.063   -3.06e-05       0.001
# change_value_14_19              -1.769e-07   3.41e-07     -0.519      0.604   -8.45e-07    4.91e-07
# change_part_rented_14_19           -0.0253      0.006     -3.996      0.000      -0.038      -0.013
# change_part_white_14_19            -0.0171      0.008     -2.244      0.025      -0.032      -0.002
# change_part_black_14_19            -0.0284      0.009     -3.030      0.002      -0.047      -0.010
# change_part_latx_14_19             -0.0197      0.007     -2.676      0.007      -0.034      -0.005
# change_part_college_14_19          -0.0027      0.007     -0.402      0.688      -0.016       0.010
# change_part_unemployed_14_19        0.0167      0.009      1.853      0.064      -0.001       0.034
# change_part_hh_kids_14_19          -0.0090      0.006     -1.535      0.125      -0.020       0.002
# change_part_female_head_14_19      -0.0524      0.016     -3.290      0.001      -0.084      -0.021
# change_part_poverty_14_19           0.0049      0.003      1.424      0.155      -0.002       0.012
# change_part_vacant_14_19           -0.0190      0.009     -2.013      0.044      -0.038      -0.000
# dist_to_nearest_highrenttract   -8.663e-05   3.24e-05     -2.675      0.007      -0.000   -2.32e-05
# dist_to_nearest_highchangetract -5.472e-05   6.01e-05     -0.910      0.363      -0.000    6.31e-05
# pctbuilt                            0.0304      0.014      2.246      0.025       0.004       0.057
# pctsold                             0.0302      0.008      3.935      0.000       0.015       0.045
# ===================================================================================================
