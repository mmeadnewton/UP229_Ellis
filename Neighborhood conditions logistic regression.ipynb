# %% [markdown]
# Running a logistic regression on the prepared dataset

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import statsmodels.api as sm
from statsmodels.discrete.discrete_model import Probit

# %%
parcelsjoindf4=pd.read_csv('/Users/alexanderferrer/Documents/GitHub/UP229_Ellis/parcels_finaldf.csv')
# Out:
# /Applications/anaconda3/envs/UP299/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
summarystatdf=parcelsjoindf4[['units_total','sqft_total','yearbuilt_avg',
                       'median_income_2019','median_rent_2019','median_value_2019','part_black_2019',
                       'part_latx_2019', 'part_white_2019', 'part_female_head_2019', 'part_hh_kids_2019',
                       'part_rented_2019', 'part_unemployed_2019', 'part_poverty_2019', 'part_vacant_2019',
                       'part_college_2019','median_income_2014','median_rent_2014','median_value_2014','part_black_2014',
                       'part_latx_2014', 'part_white_2014', 'part_female_head_2014', 'part_hh_kids_2014',
                        'part_rented_2014', 'part_unemployed_2014', 'part_poverty_2014', 'part_vacant_2014',
                       'part_college_2014','change_rent_14_19', 'change_value_14_19', 'change_part_rented_14_19',
                       'change_part_white_14_19', 'change_part_black_14_19', 'change_part_latx_14_19',
                       'change_part_college_14_19', 'change_part_unemployed_14_19', 'change_part_hh_kids_14_19',
                       'change_part_female_head_14_19', 'change_part_poverty_14_19', 'change_part_vacant_14_19',
                       'dist_to_nearest_highrenttract', 'dist_to_nearest_highchangetract','pctbuilt','pctsold' ]].agg(["count","mean","std"])
summarystatdf
# Out:
#          units_total     sqft_total  yearbuilt_avg  median_income_2019  \
# count  100140.000000  100140.000000  100140.000000       100140.000000
# mean        6.232594    5120.825335    1937.454484        59434.744357
# std        15.753543   13646.175242      19.017924        26459.086623
#
#        median_rent_2019  median_value_2019  part_black_2019  part_latx_2019  \
# count     100140.000000      100140.000000    100140.000000   100140.000000
# mean        1429.465289      679136.409452        10.822712       53.120573
# std          377.260626      335927.978379        13.787810       27.802960
#
#        part_white_2019  part_female_head_2019  ...  change_part_college_14_19  \
# count    100140.000000          100140.000000  ...              100140.000000
# mean         24.116878              17.752176  ...                  -0.752131
# std          25.656253               5.510955  ...                   6.147824
#
#        change_part_unemployed_14_19  change_part_hh_kids_14_19  \
# count                 100140.000000              100140.000000
# mean                      -5.665440                  -3.821015
# std                        4.772338                   7.126743
#
#        change_part_female_head_14_19  change_part_poverty_14_19  \
# count                  100140.000000              100140.000000
# mean                        5.982941                  -8.418742
# std                         5.787951                  11.844969
#
#        change_part_vacant_14_19  dist_to_nearest_highrenttract  \
# count             100140.000000                  100140.000000
# mean                   0.120306                    1775.176472
# std                    5.028011                    1880.241243
#
#        dist_to_nearest_highchangetract       pctbuilt        pctsold
# count                    100140.000000  100140.000000  100140.000000
# mean                        804.077293       1.158114      20.426186
# std                         895.771115       1.949679       4.211663
#
# [3 rows x 45 columns]

# %%
ellisedsummarydf=parcelsjoindf4[parcelsjoindf4['ellis_status']==1]

ellisedsummarydf=ellisedsummarydf[['units_total','sqft_total','yearbuilt_avg',
                       'median_income_2019','median_rent_2019','median_value_2019','part_black_2019',
                       'part_latx_2019', 'part_white_2019', 'part_female_head_2019', 'part_hh_kids_2019',
                       'part_rented_2019', 'part_unemployed_2019', 'part_poverty_2019', 'part_vacant_2019',
                       'part_college_2019','median_income_2014','median_rent_2014','median_value_2014','part_black_2014',
                       'part_latx_2014', 'part_white_2014', 'part_female_head_2014', 'part_hh_kids_2014',
                        'part_rented_2014', 'part_unemployed_2014', 'part_poverty_2014', 'part_vacant_2014',
                       'part_college_2014','change_rent_14_19', 'change_value_14_19', 'change_part_rented_14_19',
                       'change_part_white_14_19', 'change_part_black_14_19', 'change_part_latx_14_19',
                       'change_part_college_14_19', 'change_part_unemployed_14_19', 'change_part_hh_kids_14_19',
                       'change_part_female_head_14_19', 'change_part_poverty_14_19', 'change_part_vacant_14_19',
                       'dist_to_nearest_highrenttract', 'dist_to_nearest_highchangetract','pctbuilt','pctsold' ]].agg(["count","mean","std"])

# %%
summarystatdf.to_csv('/Users/alexanderferrer/Documents/GitHub/UP229_Ellis/summarystatdf.csv')

# %%
ellisedsummarydf.to_csv('/Users/alexanderferrer/Documents/GitHub/UP229_Ellis/EEsummarystatdf.csv')

# %%
data=parcelsjoindf4[['units_total','yearbuilt_avg',
                    'median_income_2014','median_rent_2014','part_black_2014',
                    'part_latx_2014', 'part_female_head_2014', 'part_hh_kids_2014',
                    'part_rented_2014', 'part_unemployed_2014', 'part_vacant_2014',
                    'part_college_2014','dist_to_nearest_highrenttract',
                     'ellis_status']]

Y =data['ellis_status']
X =data.drop(['ellis_status'],1)
X = sm.add_constant(X)
log_reg = sm.Logit(Y, X).fit()

print(log_reg.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.057296
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           ellis_status   No. Observations:               100140
# Model:                          Logit   Df Residuals:                   100126
# Method:                           MLE   Df Model:                           13
# Date:                Tue, 15 Jun 2021   Pseudo R-squ.:                 0.05191
# Time:                        21:10:56   Log-Likelihood:                -5737.7
# converged:                       True   LL-Null:                       -6051.8
# Covariance Type:            nonrobust   LLR p-value:                7.027e-126
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                            20.2029      3.667      5.509      0.000      13.016      27.390
# units_total                      -0.0832      0.010     -8.417      0.000      -0.103      -0.064
# yearbuilt_avg                    -0.0140      0.002     -7.379      0.000      -0.018      -0.010
# median_income_2014             1.336e-05   3.61e-06      3.698      0.000    6.28e-06    2.04e-05
# median_rent_2014                 -0.0005      0.000     -2.176      0.030      -0.001   -5.21e-05
# part_black_2014                   0.0021      0.003      0.677      0.499      -0.004       0.008
# part_latx_2014                   -0.0094      0.003     -2.967      0.003      -0.016      -0.003
# part_female_head_2014             0.0365      0.015      2.490      0.013       0.008       0.065
# part_hh_kids_2014                 0.0010      0.005      0.222      0.824      -0.008       0.010
# part_rented_2014                  0.0410      0.003     13.401      0.000       0.035       0.047
# part_unemployed_2014             -0.0227      0.009     -2.572      0.010      -0.040      -0.005
# part_vacant_2014                  0.0285      0.009      3.109      0.002       0.011       0.046
# part_college_2014                -0.0014      0.006     -0.229      0.818      -0.014       0.011
# dist_to_nearest_highrenttract -8.246e-05   3.01e-05     -2.743      0.006      -0.000   -2.35e-05
# =================================================================================================

# %%
data1=parcelsjoindf4[['units_total','yearbuilt_avg',
                    'median_income_2019','median_rent_2019','part_white_2019',
                    'part_female_head_2019', 'part_hh_kids_2019',
                    'part_rented_2019', 'part_vacant_2019',
                    'part_college_2019','dist_to_nearest_highrenttract', 'dist_to_nearest_highchangetract',
                      'pctbuilt','pctsold','landlord_iscorp']]

Y1 =data1['landlord_iscorp']
X1 =data1.drop(['landlord_iscorp'],1)
X1 = sm.add_constant(X1)
log_reg1 = sm.Logit(Y1, X1).fit()

print(log_reg1.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.425044
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:        landlord_iscorp   No. Observations:               100140
# Model:                          Logit   Df Residuals:                   100125
# Method:                           MLE   Df Model:                           14
# Date:                Tue, 15 Jun 2021   Pseudo R-squ.:                  0.1442
# Time:                        21:35:38   Log-Likelihood:                -42564.
# converged:                       True   LL-Null:                       -49738.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                             -23.6858      0.985    -24.055      0.000     -25.616     -21.756
# units_total                         0.0863      0.001     63.724      0.000       0.084       0.089
# yearbuilt_avg                       0.0106      0.001     20.781      0.000       0.010       0.012
# median_income_2019              -3.379e-06   8.46e-07     -3.993      0.000   -5.04e-06   -1.72e-06
# median_rent_2019                    0.0001   4.86e-05      3.013      0.003    5.12e-05       0.000
# part_white_2019                     0.0038      0.001      5.092      0.000       0.002       0.005
# part_female_head_2019              -0.0049      0.002     -1.968      0.049      -0.010   -1.93e-05
# part_hh_kids_2019                  -0.0017      0.001     -1.454      0.146      -0.004       0.001
# part_rented_2019                    0.0139      0.001     18.482      0.000       0.012       0.015
# part_vacant_2019                    0.0062      0.002      2.808      0.005       0.002       0.011
# part_college_2019                  -0.0115      0.002     -6.537      0.000      -0.015      -0.008
# dist_to_nearest_highrenttract     3.35e-06   7.29e-06      0.460      0.646   -1.09e-05    1.76e-05
# dist_to_nearest_highchangetract -4.168e-05   1.45e-05     -2.876      0.004   -7.01e-05   -1.33e-05
# pctbuilt                           -0.0089      0.005     -1.893      0.058      -0.018       0.000
# pctsold                             0.0230      0.002     10.168      0.000       0.019       0.027
# ===================================================================================================

# %%
data2=parcelsjoindf4[['units_total','yearbuilt_avg',
                    'change_rent_14_19', 'change_part_rented_14_19',
                    'change_part_black_14_19', 'change_part_latx_14_19',
                    'change_part_college_14_19', 'change_part_hh_kids_14_19',
                    'change_part_female_head_14_19', 'change_part_vacant_14_19',
                    'dist_to_nearest_highrenttract','pctbuilt','pctsold','landlord_iscorp']]

Y2 =data2['landlord_iscorp']
X2 =data2.drop(['landlord_iscorp'],1)
X2 = sm.add_constant(X2)
log_reg2 = sm.Logit(Y2, X2).fit()

print(log_reg2.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.428576
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:        landlord_iscorp   No. Observations:               100140
# Model:                          Logit   Df Residuals:                   100126
# Method:                           MLE   Df Model:                           13
# Date:                Tue, 15 Jun 2021   Pseudo R-squ.:                  0.1371
# Time:                        21:36:55   Log-Likelihood:                -42918.
# converged:                       True   LL-Null:                       -49738.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                           -21.7461      0.958    -22.710      0.000     -23.623     -19.869
# units_total                       0.0932      0.001     69.125      0.000       0.091       0.096
# yearbuilt_avg                     0.0097      0.000     19.710      0.000       0.009       0.011
# change_rent_14_19                 0.0002   5.38e-05      3.603      0.000    8.84e-05       0.000
# change_part_rented_14_19          0.0072      0.002      4.737      0.000       0.004       0.010
# change_part_black_14_19           0.0099      0.002      4.421      0.000       0.006       0.014
# change_part_latx_14_19           -0.0020      0.002     -1.280      0.200      -0.005       0.001
# change_part_college_14_19         0.0018      0.001      1.196      0.232      -0.001       0.005
# change_part_hh_kids_14_19      5.308e-05      0.001      0.040      0.968      -0.003       0.003
# change_part_female_head_14_19     0.0236      0.002     15.685      0.000       0.021       0.027
# change_part_vacant_14_19          0.0139      0.002      7.686      0.000       0.010       0.017
# dist_to_nearest_highrenttract -3.176e-05   5.77e-06     -5.507      0.000   -4.31e-05   -2.05e-05
# pctbuilt                         -0.0051      0.005     -1.086      0.278      -0.014       0.004
# pctsold                           0.0341      0.002     15.307      0.000       0.030       0.038
# =================================================================================================

# %%
data3=parcelsjoindf4[['units_total','sqft_total','yearbuilt_avg',
                    'median_income_2019','median_rent_2019','median_value_2019','part_black_2019',
                    'part_latx_2019', 'part_white_2019', 'part_female_head_2019', 'part_hh_kids_2019',
                    'part_rented_2019', 'part_unemployed_2019', 'part_poverty_2019', 'part_vacant_2019',
                    'part_college_2019','change_rent_14_19', 'change_value_14_19', 'change_part_rented_14_19',
                    'change_part_white_14_19', 'change_part_black_14_19', 'change_part_latx_14_19',
                    'change_part_college_14_19', 'change_part_unemployed_14_19', 'change_part_hh_kids_14_19',
                    'change_part_female_head_14_19', 'change_part_poverty_14_19', 'change_part_vacant_14_19',
                    'dist_to_nearest_highrenttract', 'dist_to_nearest_highchangetract','pctbuilt','pctsold','ellis_status']]

Y3 =data3['ellis_status']
X3 =data3.drop(['ellis_status'],1)
X3 = sm.add_constant(X3)
log_reg3 = sm.Logit(Y3, X3).fit()

print(log_reg3.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.056604
#          Iterations 11
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           ellis_status   No. Observations:               100140
# Model:                          Logit   Df Residuals:                   100107
# Method:                           MLE   Df Model:                           32
# Date:                Thu, 10 Jun 2021   Pseudo R-squ.:                 0.06337
# Time:                        21:34:40   Log-Likelihood:                -5668.3
# converged:                       True   LL-Null:                       -6051.8
# Covariance Type:            nonrobust   LLR p-value:                1.286e-140
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              18.7164      3.853      4.858      0.000      11.165      26.268
# units_total                        -0.0224      0.017     -1.323      0.186      -0.056       0.011
# sqft_total                         -0.0001   2.52e-05     -4.273      0.000      -0.000   -5.82e-05
# yearbuilt_avg                      -0.0132      0.002     -6.666      0.000      -0.017      -0.009
# median_income_2019               2.703e-06   3.41e-06      0.792      0.428   -3.99e-06    9.39e-06
# median_rent_2019                   -0.0002      0.000     -0.919      0.358      -0.001       0.000
# median_value_2019               -9.776e-09   2.62e-07     -0.037      0.970   -5.24e-07    5.05e-07
# part_black_2019                     0.0022      0.005      0.458      0.647      -0.007       0.011
# part_latx_2019                     -0.0128      0.004     -3.008      0.003      -0.021      -0.004
# part_white_2019                    -0.0052      0.004     -1.442      0.149      -0.012       0.002
# part_female_head_2019               0.0285      0.020      1.454      0.146      -0.010       0.067
# part_hh_kids_2019                   0.0139      0.006      2.436      0.015       0.003       0.025
# part_rented_2019                    0.0395      0.004     11.258      0.000       0.033       0.046
# part_unemployed_2019               -0.0003      0.014     -0.025      0.980      -0.028       0.027
# part_poverty_2019                  -0.0026      0.004     -0.668      0.504      -0.010       0.005
# part_vacant_2019                    0.0544      0.011      4.955      0.000       0.033       0.076
# part_college_2019                  -0.0270      0.008     -3.272      0.001      -0.043      -0.011
# change_rent_14_19                   0.0005      0.000      1.654      0.098   -9.29e-05       0.001
# change_value_14_19               2.463e-08   3.42e-07      0.072      0.943   -6.46e-07    6.95e-07
# change_part_rented_14_19           -0.0241      0.006     -3.834      0.000      -0.036      -0.012
# change_part_white_14_19            -0.0173      0.008     -2.287      0.022      -0.032      -0.002
# change_part_black_14_19            -0.0268      0.009     -2.857      0.004      -0.045      -0.008
# change_part_latx_14_19             -0.0181      0.007     -2.467      0.014      -0.032      -0.004
# change_part_college_14_19          -0.0030      0.007     -0.442      0.659      -0.016       0.010
# change_part_unemployed_14_19        0.0171      0.009      1.889      0.059      -0.001       0.035
# change_part_hh_kids_14_19          -0.0098      0.006     -1.675      0.094      -0.021       0.002
# change_part_female_head_14_19      -0.0471      0.016     -2.968      0.003      -0.078      -0.016
# change_part_poverty_14_19           0.0061      0.003      1.791      0.073      -0.001       0.013
# change_part_vacant_14_19           -0.0178      0.010     -1.875      0.061      -0.037       0.001
# dist_to_nearest_highrenttract    -9.66e-05   3.29e-05     -2.938      0.003      -0.000   -3.22e-05
# dist_to_nearest_highchangetract   -6.7e-05   6.05e-05     -1.108      0.268      -0.000    5.15e-05
# pctbuilt                            0.0330      0.013      2.451      0.014       0.007       0.059
# pctsold                             0.0288      0.008      3.739      0.000       0.014       0.044
# ===================================================================================================
