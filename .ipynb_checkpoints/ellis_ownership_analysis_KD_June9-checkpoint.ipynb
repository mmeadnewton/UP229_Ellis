# %% [markdown]
# Import ellis_joined, from kernel in preceeding notebook which details the cleaning and joing process.
#
# We are now going to use another assessor's dataset from 2019, and concern ourselves with the period of 2014-2019 in particuar in order to study the determinants of the ellis act on the property level during this period of intensive use.
#
# Datasets:
#
# Ellis Act Filing Records 2007- Present (May 2021): https://hcidla2.lacity.org/ELLIS - base dataset, now joined, see previous notebook - we will be extracting data from years 2015-2019 for this study.
#
# Census tract level demographic and econmoic data: ACS 5 Years 2014 and 2019 from census api through cenpy. Index of tables https://www2.census.gov/programs-surveys/acs/tech_docs/table_shells/2019/: data for Los Angeles County Census Tracts.
#
# Los Angeles County Assessors Parcel Records (2019): Purchased by SAJE, used with permissions - used to identify parcel status, features and ownership - GEOJSON export including selected columns for LA city parcels from SAJE owned geopackage.

# %%
#Import modules: pandas/geopandas
import pandas as pd
import geopandas as gpd

# %%
ellisdf=pd.read_csv('/Users/katrinadeloso/Documents/GitHub/UP229_Ellis/ellis_joined.csv')

ellisdf.head()
# Out:
#    Unnamed: 0 application_received  application_year  council_district  \
# 0  2040031029              11/6/19              2019                 3
# 1  2040031030              12/4/19              2019                 3
# 2  2040033033              2/10/16              2016                 3
# 3  2107014004              4/21/20              2020                 3
# 4  2111025021              3/16/16              2016                 3
#
#                 address             city      zip  units_withdrawn  \
# 0  22729 W DEL VALLE ST     LOS ANGELES   91364.0                3
# 1  22727 W DEL VALLE ST  WOODLAND HILLS   91364.0                3
# 2  22431 W DEL VALLE ST  WOODLAND HILLS   91364.0                3
# 3      20327 W STAGG ST     LOS ANGELES   91306.0                3
# 4     7118 N JORDAN AVE     CANOGA PARK   91303.0                2
#
#    replacement_unit  yearbuilt  units  sqftmain  center_lat  center_lon  \
# 0               0.0     1955.0    3.0    1860.0   34.165880 -118.621319
# 1               0.0     1955.0    3.0    1869.0   34.165929 -118.621164
# 2               0.0     1955.0    3.0    1869.0   34.167389 -118.616525
# 3               0.0     1910.0    3.0    2446.0   34.211389 -118.576350
# 4               9.0     1947.0    2.0    1489.0   34.199760 -118.602505
#
#                                        geometry
# 0  POINT (-13204864.81828771 4051097.450097568)
# 1  POINT (-13204847.61386041 4051104.006178072)
# 2   POINT (-13204331.1860447 4051300.523521864)
# 3  POINT (-13199858.95667153 4057221.803746735)
# 4   POINT (-13202770.5034817 4055656.567431433)

# %%
ellisdf.rename(columns={'Unnamed: 0': 'ain',}, inplace=True)

ellisdf.head()
# Out:
#           ain application_received  application_year  council_district  \
# 0  2040031029              11/6/19              2019                 3
# 1  2040031030              12/4/19              2019                 3
# 2  2040033033              2/10/16              2016                 3
# 3  2107014004              4/21/20              2020                 3
# 4  2111025021              3/16/16              2016                 3
#
#                 address             city      zip  units_withdrawn  \
# 0  22729 W DEL VALLE ST     LOS ANGELES   91364.0                3
# 1  22727 W DEL VALLE ST  WOODLAND HILLS   91364.0                3
# 2  22431 W DEL VALLE ST  WOODLAND HILLS   91364.0                3
# 3      20327 W STAGG ST     LOS ANGELES   91306.0                3
# 4     7118 N JORDAN AVE     CANOGA PARK   91303.0                2
#
#    replacement_unit  yearbuilt  units  sqftmain  center_lat  center_lon  \
# 0               0.0     1955.0    3.0    1860.0   34.165880 -118.621319
# 1               0.0     1955.0    3.0    1869.0   34.165929 -118.621164
# 2               0.0     1955.0    3.0    1869.0   34.167389 -118.616525
# 3               0.0     1910.0    3.0    2446.0   34.211389 -118.576350
# 4               9.0     1947.0    2.0    1489.0   34.199760 -118.602505
#
#                                        geometry
# 0  POINT (-13204864.81828771 4051097.450097568)
# 1  POINT (-13204847.61386041 4051104.006178072)
# 2   POINT (-13204331.1860447 4051300.523521864)
# 3  POINT (-13199858.95667153 4057221.803746735)
# 4   POINT (-13202770.5034817 4055656.567431433)

# %%
ellisdf['application_date'] = pd.to_datetime(ellisdf['application_received'])

print(ellisdf['application_date'].unique())
# Out:
# ['2019-11-06T00:00:00.000000000' '2019-12-04T00:00:00.000000000'
#  '2016-02-10T00:00:00.000000000' ... '2020-07-20T00:00:00.000000000'
#  '2018-02-13T00:00:00.000000000' '2017-01-12T00:00:00.000000000']

# %% [markdown]
# In this case we are only interested in Ellis Act Evictions from 2014 to 2019, so we will create a new dataset dropping the others.

# %%
studyellisdf=ellisdf[ellisdf['application_year'].between(2015, 2019)]

print(studyellisdf['application_year'].unique())
# Out:
# [2019 2016 2015 2018 2017]

# %%
#studyellisdf.to_csv("studyellisdf.csv")

# %%
parcelsdf=pd.read_csv('/Users/katrinadeloso/Documents/GitHub/UP229_Ellis/assessor_2019_la.csv')

parcelsdf.columns
# Out:
# /opt/anaconda3/envs/up229/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (27) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# Index(['fid', 'CENTER_LON', 'YearBuilt5', 'YearBuilt4', 'YearBuilt1',
#        'UseType', 'YearBuilt2', 'APN', 'Bedrooms1', 'Bedrooms2', 'Bedrooms3',
#        'Bedrooms4', 'Bedrooms5', 'UseDescription', 'MailAddress', 'SQFTmain2',
#        'SQFTmain3', 'SQFTmain1', 'SQFTmain4', 'SQFTmain5', 'MailCity',
#        'Units1', 'Units3', 'Units2', 'Units5', 'Units4', 'OwnerFullName',
#        'AgencyName', 'AIN', 'Bathrooms5', 'Bathrooms4', 'Bathrooms1',
#        'Bathrooms3', 'Bathrooms2', 'SitusFullAddress', 'Shape.STArea()',
#        'Shape.STLength()', 'YearBuilt3', 'CENTER_LAT', 'LS1 Sale Amount',
#        'LS1 Sale Date', 'LS2 Sale Amount', 'LS2 Sale Date'],
#       dtype='object')

# %%
parcelsdf.columns=parcelsdf.columns.str.lower()

parcelsdf.columns
# Out:
# Index(['fid', 'center_lon', 'yearbuilt5', 'yearbuilt4', 'yearbuilt1',
#        'usetype', 'yearbuilt2', 'apn', 'bedrooms1', 'bedrooms2', 'bedrooms3',
#        'bedrooms4', 'bedrooms5', 'usedescription', 'mailaddress', 'sqftmain2',
#        'sqftmain3', 'sqftmain1', 'sqftmain4', 'sqftmain5', 'mailcity',
#        'units1', 'units3', 'units2', 'units5', 'units4', 'ownerfullname',
#        'agencyname', 'ain', 'bathrooms5', 'bathrooms4', 'bathrooms1',
#        'bathrooms3', 'bathrooms2', 'situsfulladdress', 'shape.starea()',
#        'shape.stlength()', 'yearbuilt3', 'center_lat', 'ls1 sale amount',
#        'ls1 sale date', 'ls2 sale amount', 'ls2 sale date'],
#       dtype='object')

# %%
parcelsdf.columns = parcelsdf.columns.str.replace(' ','_')

parcelsdf.columns
# Out:
# Index(['fid', 'center_lon', 'yearbuilt5', 'yearbuilt4', 'yearbuilt1',
#        'usetype', 'yearbuilt2', 'apn', 'bedrooms1', 'bedrooms2', 'bedrooms3',
#        'bedrooms4', 'bedrooms5', 'usedescription', 'mailaddress', 'sqftmain2',
#        'sqftmain3', 'sqftmain1', 'sqftmain4', 'sqftmain5', 'mailcity',
#        'units1', 'units3', 'units2', 'units5', 'units4', 'ownerfullname',
#        'agencyname', 'ain', 'bathrooms5', 'bathrooms4', 'bathrooms1',
#        'bathrooms3', 'bathrooms2', 'situsfulladdress', 'shape.starea()',
#        'shape.stlength()', 'yearbuilt3', 'center_lat', 'ls1_sale_amount',
#        'ls1_sale_date', 'ls2_sale_amount', 'ls2_sale_date'],
#       dtype='object')

# %% [markdown]
# We need to find total values for the parcels' characteristics, so first we need to convert the fields to in and nulls to zeros.

# %%
parcelsdf[['bedrooms1', 'bedrooms2', 'bedrooms3','bedrooms4', 'bedrooms5','sqftmain2','sqftmain3','sqftmain1', 'sqftmain4', 'sqftmain5','units1', 'units3', 'units2', 'units5', 'units4','bathrooms5', 'bathrooms4', 'bathrooms1','bathrooms3', 'bathrooms2']]= parcelsdf[['bedrooms1', 'bedrooms2', 'bedrooms3','bedrooms4', 'bedrooms5','sqftmain2','sqftmain3','sqftmain1', 'sqftmain4', 'sqftmain5','units1', 'units3', 'units2', 'units5', 'units4','bathrooms5', 'bathrooms4', 'bathrooms1','bathrooms3', 'bathrooms2']].fillna(0)

# %%
parcelsdf[['bedrooms1', 'bedrooms2', 'bedrooms3','bedrooms4', 'bedrooms5','sqftmain2','sqftmain3','sqftmain1', 'sqftmain4', 'sqftmain5','units1', 'units3', 'units2', 'units5', 'units4','bathrooms5', 'bathrooms4', 'bathrooms1','bathrooms3', 'bathrooms2']]= parcelsdf[['bedrooms1', 'bedrooms2', 'bedrooms3','bedrooms4', 'bedrooms5','sqftmain2','sqftmain3','sqftmain1', 'sqftmain4', 'sqftmain5','units1', 'units3', 'units2', 'units5', 'units4','bathrooms5', 'bathrooms4', 'bathrooms1','bathrooms3', 'bathrooms2']].astype(int)

# %%
parcelsdf['units_total']=parcelsdf['units1']+parcelsdf['units2']+parcelsdf['units3']+parcelsdf['units4']+parcelsdf['units5']

parcelsdf['bedrooms_total']=parcelsdf['bedrooms1']+parcelsdf['bedrooms2']+parcelsdf['bedrooms3']+parcelsdf['bedrooms4']+parcelsdf['bedrooms5']

parcelsdf['bathrooms_total']=parcelsdf['bathrooms1']+parcelsdf['bathrooms2']+parcelsdf['bathrooms3']+parcelsdf['bathrooms4']+parcelsdf['bathrooms5']

parcelsdf['sqft_total']=parcelsdf['sqftmain1']+parcelsdf['sqftmain2']+parcelsdf['sqftmain3']+parcelsdf['sqftmain4']+parcelsdf['sqftmain5']

# %% [markdown]
# We also need to find the average built age of the structures on the parcel. However some are inccorectly recorded as 0, and we will need to convert those to null first.

# %%
import numpy as np

# %%
parcelsdf[['yearbuilt5', 'yearbuilt4', 'yearbuilt1','yearbuilt2','yearbuilt3']]=parcelsdf[['yearbuilt5', 'yearbuilt4', 'yearbuilt1','yearbuilt2','yearbuilt3']].replace(0,np.nan)

# %%
parcelsdf['yearbuilt_avg']=parcelsdf[['yearbuilt5', 'yearbuilt4', 'yearbuilt1','yearbuilt2','yearbuilt3']].mean(axis=1)

parcelsdf['yearbuilt_avg']=parcelsdf['yearbuilt_avg'].astype(int)

print(parcelsdf.yearbuilt_avg.unique())
# Out:
# [1961 1948 1981 1926 1952 1950 1977 1956 1980 1959 1954 1973 1945 1901
#  1912 1908 1933 1895 1906 1913 1935 1890 1914 1921 1931 1922 1898 1905
#  1927 1923 1953 1904 1909 1900 1911 1929 1885 1936 1919 2003 1907 1893
#  1944 1941 1902 1880 1887 1899 1940 2006 1896 1918 1947 1892 1963 1897
#  1910 1978 1903 2001 1966 1946 1939 1975 1938 1951 1924 1915 2004 1937
#  1920 1960 1965 2007 1986 2002 1964 1958 2010 1916 1979 1962 1957 1990
#  1932 2009 1997 1991 1930 1993 1992 1928 2011 1985 1943 1949 1988 1925
#  1976 1917 1891 2016 1942 2008 2014 1999 1881 1934 1984 1968 1989 1884
#  1972 1971 1967 1983 1994 1955 1969 2005 1982 1987 1998 1996 2017 1894
#  1995 1889 2015 1970 1974 1888 2013 2000 2012 2018 1886 1882 1804 1883
#  2019 1833 1875 1867 1857 1819 1866 1870 1861 1827 1815 1828 1806 1879
#  1873 1864 1834 1863 1872 1852 1877 1868 1808 1869 1865 1855 1812 1825
#  1859]

# %% [markdown]
# Now we can generate some more interesting parcel characteristics, in terms of built area to parcel area, and estimated density.

# %%
parcelsdf['built_to_land']=parcelsdf['sqft_total']/parcelsdf['shape.starea()']

parcelsdf['estimated_density_per_acre']=(parcelsdf['units_total']/(parcelsdf['shape.starea()']/43560))

parcelsdf.columns
# Out:
# Index(['fid', 'center_lon', 'yearbuilt5', 'yearbuilt4', 'yearbuilt1',
#        'usetype', 'yearbuilt2', 'apn', 'bedrooms1', 'bedrooms2', 'bedrooms3',
#        'bedrooms4', 'bedrooms5', 'usedescription', 'mailaddress', 'sqftmain2',
#        'sqftmain3', 'sqftmain1', 'sqftmain4', 'sqftmain5', 'mailcity',
#        'units1', 'units3', 'units2', 'units5', 'units4', 'ownerfullname',
#        'agencyname', 'ain', 'bathrooms5', 'bathrooms4', 'bathrooms1',
#        'bathrooms3', 'bathrooms2', 'situsfulladdress', 'shape.starea()',
#        'shape.stlength()', 'yearbuilt3', 'center_lat', 'ls1_sale_amount',
#        'ls1_sale_date', 'ls2_sale_amount', 'ls2_sale_date', 'units_total',
#        'bedrooms_total', 'bathrooms_total', 'sqft_total', 'yearbuilt_avg',
#        'built_to_land', 'estimated_density_per_acre'],
#       dtype='object')

# %% [markdown]
# Now, we can indentify parcels that were built or sold in the years in question

# %%
print(parcelsdf['ls1_sale_date'].unique())
# Out:
# [19741018.        0. 20191007. ... 19890527. 19721228. 20170422.]

# %%
#what happened here- how can I fix this without dropping the rows with 0?
parcelsdf['ls1_sale_date']=parcelsdf.ls1_sale_date.fillna(0)
parcelsdf['ls1_sale_date']=parcelsdf.ls1_sale_date.astype(int).astype(str)
parcelsdf['last_sold_date']=pd.to_datetime(parcelsdf['ls1_sale_date'],infer_datetime_format=True,errors='coerce')
print(parcelsdf.last_sold_date.unique())
# Out:
# ['1974-10-18T00:00:00.000000000'                           'NaT'
#  '2019-10-07T00:00:00.000000000' ... '1989-05-27T00:00:00.000000000'
#  '1972-12-28T00:00:00.000000000' '2017-04-22T00:00:00.000000000']

# %%
parcelsdf2=parcelsdf[pd.isna(parcelsdf['last_sold_date'])]
print(len(parcelsdf2))
# Out:
# 32235

# %%
parcelsdf['ls1_sale_date']=parcelsdf.ls1_sale_date.astype(int)
parcelsdf['sold_14_19']=parcelsdf.ls1_sale_date.apply(lambda x:1 if (x>20150000 and x<20200000) else 0)

sold_14_19df=parcelsdf[parcelsdf['sold_14_19']==1]

print(len(sold_14_19df))
# Out:
# 147551

# %%
parcelsdf['built_14_19']=parcelsdf.yearbuilt_avg.apply(lambda x: 1 if (x>2014 and x<2020) else 0)

built_14_19df=parcelsdf[parcelsdf['built_14_19']==1]

print(len(built_14_19df))
# Out:
# 8688

# %%
#ask about this too for text, esp wildcard characters

parcelsdf['ownerfullname']=parcelsdf['ownerfullname'].astype(str)

def process_name(parcelsdf):
    if pd.notna(parcelsdf['agencyname']):
        return 0
    elif  ',' in parcelsdf['ownerfullname'] and 'TRS' not in parcelsdf['ownerfullname'] and 'TRUST' not in parcelsdf['ownerfullname'] and 'TR' not in parcelsdf['ownerfullname'] and 'GP' not in parcelsdf['ownerfullname'] and 'LP' not in parcelsdf['ownerfullname'] and 'LLP' not in parcelsdf['ownerfullname'] and 'PARTNERS' not in parcelsdf['ownerfullname'] and 'LLC' not in parcelsdf['ownerfullname'] and 'LIMITED' not in parcelsdf['ownerfullname'] and 'LTD' not in parcelsdf['ownerfullname'] and 'PARTNERSHIP' not in parcelsdf['ownerfullname']:
        return 1
    elif 'TRS' in parcelsdf['ownerfullname'] or 'TRUST' in parcelsdf['ownerfullname'] or 'TR' in parcelsdf['ownerfullname']:
        return 2
    elif 'LP' in parcelsdf['ownerfullname'] or 'GP'in parcelsdf['ownerfullname'] or 'PARTNERS'in parcelsdf['ownerfullname'] or 'PARTNER'in parcelsdf['ownerfullname'] or 'PARTNERSHIP'in parcelsdf['ownerfullname'] :
        return 3
    elif 'LLC' in parcelsdf['ownerfullname'] or 'LLP'in parcelsdf['ownerfullname'] or 'LTD' in parcelsdf['ownerfullname'] or'LIMITED'in parcelsdf['ownerfullname']:
        return 4
    else: 
        return 5
    
parcelsdf['landlord_type']=parcelsdf.apply(process_name, axis=1)

print(parcelsdf.landlord_type.unique())
# Out:
# [2 1 5 4 3 0]

# %%
parcelsdf.landlord_type.value_counts()
# Out:
# 1    416397
# 2    232633
# 4     36027
# 5      9971
# 3      8752
# 0      1454
# Name: landlord_type, dtype: int64

# %%
#how to create a new df of ll size by counting units and counts of mailing address, then apply to original df

tempdf1=parcelsdf.groupby('mailaddress')['mailaddress'].count()

tempdf2=parcelsdf.groupby('mailaddress')['units_total'].sum()

llaggdf = pd.DataFrame({'n_ll_properties': tempdf1, 'n_ll_units': tempdf2})

# %%
print(llaggdf.head(10))
# Out:
#                                    n_ll_properties  n_ll_units
# mailaddress
#  1 16 7 SAIWAI CHO SHIKI SHI                     1          23
#  1 RUE DU MOULIN RENARD                          1           1
#  1-10-4 KAMINOGE SETAGAYA KU                     1           5
#  1-14-5 YAKUIN-CHUO-KU                           1           1
#  1-20-23 SAKAI MUSASHIMO-SHI                     1           1
#  1-8-5 HARUMI NO1706 CHOU KU                     1           1
#  10 JALAN 13/6 GREENVILLE                        1           1
#  10/F SURSON COMM BLVD 142 AUSTIN                1           1
#  100701 RED RYDER RD                             1           1
#  104-375 WATER ST VANCOUVER                      1           4

# %%
parcelsdf=parcelsdf.join(llaggdf, how='left', on='mailaddress')

parcelsdf.head(10)
# Out:
#    fid  center_lon  yearbuilt5  yearbuilt4  yearbuilt1      usetype  \
# 0    5 -118.434714         NaN         NaN      1961.0  Residential
# 1    7 -118.509913         NaN         NaN      1948.0  Residential
# 2    8 -118.434041         NaN         NaN      1981.0  Residential
# 3   21 -118.437185         NaN         NaN      1926.0  Residential
# 4   44 -118.511595         NaN         NaN      1952.0  Residential
# 5   47 -118.510880         NaN         NaN      1950.0  Residential
# 6   58 -118.435081         NaN         NaN      1977.0  Residential
# 7   64 -118.511546         NaN         NaN      1956.0  Residential
# 8  102 -118.511540         NaN         NaN      1961.0  Residential
# 9  122 -118.437277         NaN         NaN      1961.0  Residential
#
#    yearbuilt2           apn  bedrooms1  bedrooms2  ...  sqft_total  \
# 0         NaN  4357-015-017          3          0  ...        2370
# 1         NaN  2690-001-025          3          0  ...        1969
# 2         NaN  4357-009-014          4          0  ...        6180
# 3         NaN  4357-011-006          7          0  ...        6406
# 4         NaN  2768-018-013          4          0  ...        2773
# 5         NaN  2690-003-012          3          0  ...        2369
# 6         NaN  4357-015-006          3          0  ...        2644
# 7         NaN  2766-012-018          5          0  ...        3576
# 8         NaN  2768-022-022          5          0  ...        2981
# 9         NaN  4357-004-018          2          0  ...        1709
#
#    yearbuilt_avg  built_to_land estimated_density_per_acre last_sold_date  \
# 0           1961       0.173059                   3.180789     1974-10-18
# 1           1948       0.071572                   1.583370            NaT
# 2           1981       0.032764                   0.230936     2019-10-07
# 3           1926       0.038333                   0.260656     1996-07-15
# 4           1952       0.146416                   2.299997     1999-10-28
# 5           1950       0.079438                   1.460660     1997-09-25
# 6           1977       0.046179                   0.760803     2003-08-08
# 7           1956       0.176879                   2.154601     1997-10-03
# 8           1961       0.190678                   2.786298            NaT
# 9           1961       0.113921                   2.903675     1990-05-24
#
#    sold_14_19  built_14_19  landlord_type  n_ll_properties  n_ll_units
# 0           0            0              2              1.0         1.0
# 1           0            0              2              3.0         3.0
# 2           1            0              2              4.0        12.0
# 3           0            0              1              1.0         1.0
# 4           0            0              2              1.0         1.0
# 5           0            0              2              3.0         3.0
# 6           0            0              1              1.0         1.0
# 7           0            0              2              1.0         1.0
# 8           0            0              2              1.0         1.0
# 9           0            0              5              3.0         3.0
#
# [10 rows x 56 columns]

# %%
#We also need a bool indicator of the corporate status for regression

parcelsdf['landlord_iscorp']=parcelsdf.landlord_type.apply(lambda x:1 if x>2 else 0)

parcelsdf.landlord_iscorp.value_counts()
# Out:
# 0    650484
# 1     54750
# Name: landlord_iscorp, dtype: int64

# %% [markdown]
# Now, we will turn to assigning neighborhood characteristics for the parcels in question, using census data from the ACS acquired through cenpy's API tool. Index of tables https://www2.census.gov/programs-surveys/acs/tech_docs/table_shells/2019/

# %%
import requests
import cenpy
from cenpy import products

acs19=cenpy.products.ACS(2019)

# %%
vars_to_download_19 = {
    "B25064_001E": "median_rent_2019",
    "B25077_001E": "median_value_2019",
    "B03002_001E": "total_pop_2019",
    "B03002_003E": "white_2019",
    "B03002_004E": "black_2019",
    "B03002_012E": "latx_2019",
    "B25003_001E": "housing_occupied_2019",
    "B25003_003E": "housing_rented_2019",
    "B09019_007E": "hh_female_head_2019",
    "B09019_001E": "hh_total_2019",
    "B15003_001E": "educ_all_2019",
    "B15003_015E": "educ_bachelors_2019",
    "B15003_016E": "educ_masters_2019",
    "B15003_017E": "educ_professional_2019",
    "B15003_018E": "educ_doctoral_2019", 
    "B19013_001E": "median_income_2019",
    "B23025_003E": "civ_laborforce_2019",
    "B23025_005E": "civ_unemployed_2019",
    "B17001_001E": "pov_all_2019",
    "B17001_002E": "pov_extreme_2019",
    "B17001_003E": "pov_severe_2019",
    "B17001_004E": "pov_in_2019",
    "B11005_001E": "hh_kids_all_2019",
    "B11005_002E": "hh_kids_yes_2019",
    "B25002_001E": "units_all_2019",
    "B25002_003E": "units_vacant_2019"
    
}
vars_to_download_l_19 = list(vars_to_download_19.keys())

# %%
tracts19gdf=products.ACS(2019).from_county('Los Angeles, CA',level='tract',variables=vars_to_download_l_19)
# Out:
# /opt/anaconda3/envs/up229/lib/python3.8/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
print(tracts19gdf.head(10))
# Out:
#          GEOID                                           geometry  \
# 0  06037670403  POLYGON ((-13177840.910 3998757.250, -13177839...
# 1  06037670202  POLYGON ((-13177176.670 4000044.060, -13177164...
# 2  06037670701  POLYGON ((-13171166.080 3997280.030, -13171138...
# 3  06037293307  POLYGON ((-13170065.910 4000308.450, -13170065...
# 4  06037296300  POLYGON ((-13170120.120 3995289.290, -13170111...
# 5  06037297201  POLYGON ((-13168495.190 3991594.850, -13168494...
# 6  06037296600  POLYGON ((-13168733.750 3993416.960, -13168733...
# 7  06037297110  POLYGON ((-13167752.470 3992927.300, -13167751...
# 8  06037296220  POLYGON ((-13167749.020 3993777.050, -13167748...
# 9  06037294510  POLYGON ((-13166314.000 4000710.020, -13166192...
#
#    B03002_001E  B03002_003E  B03002_004E  B03002_012E  B09019_001E  \
# 0       2733.0       1422.0         26.0        116.0       2733.0
# 1       2637.0       1473.0         25.0        481.0       2637.0
# 2       7185.0       3592.0         29.0       1841.0       7185.0
# 3       2284.0        259.0        183.0       1384.0       2284.0
# 4       5027.0       2082.0        458.0       1171.0       5027.0
# 5       4505.0        848.0        327.0       2892.0       4505.0
# 6       5358.0        795.0        313.0       4045.0       5358.0
# 7       4649.0        758.0        515.0       2988.0       4649.0
# 8       4447.0        412.0        568.0       2902.0       4447.0
# 9       5082.0         98.0         10.0       4958.0       5082.0
#
#    B09019_007E  B11005_001E  B11005_002E  ...  B25002_001E  B25002_003E  \
# 0        351.0        992.0        364.0  ...       1021.0         29.0
# 1        397.0        889.0        319.0  ...        915.0         26.0
# 2       1101.0       2497.0        749.0  ...       2513.0         16.0
# 3        431.0        914.0        223.0  ...        959.0         45.0
# 4       1030.0       2054.0        627.0  ...       2054.0          0.0
# 5        645.0       1467.0        631.0  ...       1502.0         35.0
# 6       1082.0       1948.0        564.0  ...       2118.0        170.0
# 7        800.0       1558.0        501.0  ...       1704.0        146.0
# 8       1018.0       1775.0        553.0  ...       1917.0        142.0
# 9        451.0       1079.0        592.0  ...       1161.0         82.0
#
#    B25003_001E  B25003_003E  B25064_001E  B25077_001E  \
# 0        992.0        100.0       3100.0    1145600.0
# 1        889.0         43.0       3400.0    1418400.0
# 2       2497.0        444.0       2264.0     830200.0
# 3        914.0        697.0       1172.0     346300.0
# 4       2054.0        801.0       2066.0     482100.0
# 5       1467.0       1161.0       1544.0     448200.0
# 6       1948.0       1504.0       1439.0     483000.0
# 7       1558.0       1323.0       1149.0     473500.0
# 8       1775.0       1648.0        936.0     373100.0
# 9       1079.0        699.0       1169.0     393200.0
#
#                                                 NAME  state  county   tract
# 0  Census Tract 6704.03, Los Angeles County, Cali...     06     037  670403
# 1  Census Tract 6702.02, Los Angeles County, Cali...     06     037  670202
# 2  Census Tract 6707.01, Los Angeles County, Cali...     06     037  670701
# 3  Census Tract 2933.07, Los Angeles County, Cali...     06     037  293307
# 4  Census Tract 2963, Los Angeles County, California     06     037  296300
# 5  Census Tract 2972.01, Los Angeles County, Cali...     06     037  297201
# 6  Census Tract 2966, Los Angeles County, California     06     037  296600
# 7  Census Tract 2971.10, Los Angeles County, Cali...     06     037  297110
# 8  Census Tract 2962.20, Los Angeles County, Cali...     06     037  296220
# 9  Census Tract 2945.10, Los Angeles County, Cali...     06     037  294510
#
# [10 rows x 32 columns]

# %%
tracts19gdf=tracts19gdf.rename(columns=vars_to_download_19)
print(tracts19gdf.columns.unique())
# Out:
# Index(['GEOID', 'geometry', 'total_pop_2019', 'white_2019', 'black_2019',
#        'latx_2019', 'hh_total_2019', 'hh_female_head_2019', 'hh_kids_all_2019',
#        'hh_kids_yes_2019', 'educ_all_2019', 'educ_bachelors_2019',
#        'educ_masters_2019', 'educ_professional_2019', 'educ_doctoral_2019',
#        'pov_all_2019', 'pov_extreme_2019', 'pov_severe_2019', 'pov_in_2019',
#        'median_income_2019', 'civ_laborforce_2019', 'civ_unemployed_2019',
#        'units_all_2019', 'units_vacant_2019', 'housing_occupied_2019',
#        'housing_rented_2019', 'median_rent_2019', 'median_value_2019', 'NAME',
#        'state', 'county', 'tract'],
#       dtype='object')

# %%
tracts19gdf.columns
columns19 = ['total_pop_2019', 'white_2019', 'black_2019',
       'latx_2019', 'hh_total_2019', 'hh_female_head_2019', 'hh_kids_all_2019',
       'hh_kids_yes_2019', 'educ_all_2019', 'educ_bachelors_2019',
       'educ_masters_2019', 'educ_professional_2019', 'educ_doctoral_2019',
       'pov_all_2019', 'pov_extreme_2019', 'pov_severe_2019', 'pov_in_2019',
       'median_income_2019', 'civ_laborforce_2019', 'civ_unemployed_2019',
       'units_all_2019', 'units_vacant_2019', 'housing_occupied_2019',
       'housing_rented_2019', 'median_rent_2019', 'median_value_2019']
tracts19gdf[tracts19gdf[columns19] < 0]=np.nan
tracts19gdf.head(10)
# Out:
#          GEOID                                           geometry  \
# 0  06037670403  POLYGON ((-13177840.910 3998757.250, -13177839...
# 1  06037670202  POLYGON ((-13177176.670 4000044.060, -13177164...
# 2  06037670701  POLYGON ((-13171166.080 3997280.030, -13171138...
# 3  06037293307  POLYGON ((-13170065.910 4000308.450, -13170065...
# 4  06037296300  POLYGON ((-13170120.120 3995289.290, -13170111...
# 5  06037297201  POLYGON ((-13168495.190 3991594.850, -13168494...
# 6  06037296600  POLYGON ((-13168733.750 3993416.960, -13168733...
# 7  06037297110  POLYGON ((-13167752.470 3992927.300, -13167751...
# 8  06037296220  POLYGON ((-13167749.020 3993777.050, -13167748...
# 9  06037294510  POLYGON ((-13166314.000 4000710.020, -13166192...
#
#    total_pop_2019  white_2019  black_2019  latx_2019  hh_total_2019  \
# 0          2733.0      1422.0        26.0      116.0         2733.0
# 1          2637.0      1473.0        25.0      481.0         2637.0
# 2          7185.0      3592.0        29.0     1841.0         7185.0
# 3          2284.0       259.0       183.0     1384.0         2284.0
# 4          5027.0      2082.0       458.0     1171.0         5027.0
# 5          4505.0       848.0       327.0     2892.0         4505.0
# 6          5358.0       795.0       313.0     4045.0         5358.0
# 7          4649.0       758.0       515.0     2988.0         4649.0
# 8          4447.0       412.0       568.0     2902.0         4447.0
# 9          5082.0        98.0        10.0     4958.0         5082.0
#
#    hh_female_head_2019  hh_kids_all_2019  hh_kids_yes_2019  ...  \
# 0                351.0             992.0             364.0  ...
# 1                397.0             889.0             319.0  ...
# 2               1101.0            2497.0             749.0  ...
# 3                431.0             914.0             223.0  ...
# 4               1030.0            2054.0             627.0  ...
# 5                645.0            1467.0             631.0  ...
# 6               1082.0            1948.0             564.0  ...
# 7                800.0            1558.0             501.0  ...
# 8               1018.0            1775.0             553.0  ...
# 9                451.0            1079.0             592.0  ...
#
#    units_all_2019  units_vacant_2019  housing_occupied_2019  \
# 0          1021.0               29.0                  992.0
# 1           915.0               26.0                  889.0
# 2          2513.0               16.0                 2497.0
# 3           959.0               45.0                  914.0
# 4          2054.0                0.0                 2054.0
# 5          1502.0               35.0                 1467.0
# 6          2118.0              170.0                 1948.0
# 7          1704.0              146.0                 1558.0
# 8          1917.0              142.0                 1775.0
# 9          1161.0               82.0                 1079.0
#
#    housing_rented_2019  median_rent_2019  median_value_2019  \
# 0                100.0            3100.0          1145600.0
# 1                 43.0            3400.0          1418400.0
# 2                444.0            2264.0           830200.0
# 3                697.0            1172.0           346300.0
# 4                801.0            2066.0           482100.0
# 5               1161.0            1544.0           448200.0
# 6               1504.0            1439.0           483000.0
# 7               1323.0            1149.0           473500.0
# 8               1648.0             936.0           373100.0
# 9                699.0            1169.0           393200.0
#
#                                                 NAME  state  county   tract
# 0  Census Tract 6704.03, Los Angeles County, Cali...     06     037  670403
# 1  Census Tract 6702.02, Los Angeles County, Cali...     06     037  670202
# 2  Census Tract 6707.01, Los Angeles County, Cali...     06     037  670701
# 3  Census Tract 2933.07, Los Angeles County, Cali...     06     037  293307
# 4  Census Tract 2963, Los Angeles County, California     06     037  296300
# 5  Census Tract 2972.01, Los Angeles County, Cali...     06     037  297201
# 6  Census Tract 2966, Los Angeles County, California     06     037  296600
# 7  Census Tract 2971.10, Los Angeles County, Cali...     06     037  297110
# 8  Census Tract 2962.20, Los Angeles County, Cali...     06     037  296220
# 9  Census Tract 2945.10, Los Angeles County, Cali...     06     037  294510
#
# [10 rows x 32 columns]

# %%
tracts19gdf.dtypes
# Out:
# GEOID                       object
# geometry                  geometry
# total_pop_2019             float64
# white_2019                 float64
# black_2019                 float64
# latx_2019                  float64
# hh_total_2019              float64
# hh_female_head_2019        float64
# hh_kids_all_2019           float64
# hh_kids_yes_2019           float64
# educ_all_2019              float64
# educ_bachelors_2019        float64
# educ_masters_2019          float64
# educ_professional_2019     float64
# educ_doctoral_2019         float64
# pov_all_2019               float64
# pov_extreme_2019           float64
# pov_severe_2019            float64
# pov_in_2019                float64
# median_income_2019         float64
# civ_laborforce_2019        float64
# civ_unemployed_2019        float64
# units_all_2019             float64
# units_vacant_2019          float64
# housing_occupied_2019      float64
# housing_rented_2019        float64
# median_rent_2019           float64
# median_value_2019          float64
# NAME                        object
# state                       object
# county                      object
# tract                       object
# dtype: object

# %%
tracts19gdf['part_black_2019']=(tracts19gdf['black_2019']/tracts19gdf['total_pop_2019'])*100
tracts19gdf['part_latx_2019']=(tracts19gdf['latx_2019']/tracts19gdf['total_pop_2019'])*100
tracts19gdf['part_white_2019']=(tracts19gdf['white_2019']/tracts19gdf['total_pop_2019'])*100
tracts19gdf['part_female_head_2019']=(tracts19gdf['hh_female_head_2019']/tracts19gdf['hh_total_2019'])*100
tracts19gdf['part_hh_kids_2019']=(tracts19gdf['hh_kids_yes_2019']/tracts19gdf['hh_kids_all_2019'])*100
tracts19gdf['part_rented_2019']=(tracts19gdf['housing_rented_2019']/tracts19gdf['housing_occupied_2019'])*100
tracts19gdf['part_unemployed_2019']=(tracts19gdf['civ_unemployed_2019']/tracts19gdf['civ_laborforce_2019'])*100
tracts19gdf['part_poverty_2019']=((tracts19gdf['pov_in_2019']+tracts19gdf['pov_severe_2019']+tracts19gdf['pov_extreme_2019'])/tracts19gdf['pov_all_2019'])*100
tracts19gdf['part_vacant_2019']=(tracts19gdf['units_vacant_2019']/tracts19gdf['units_all_2019'])*100
tracts19gdf['part_college_2019']=((tracts19gdf['educ_bachelors_2019']+tracts19gdf['educ_masters_2019']+tracts19gdf['educ_doctoral_2019']+tracts19gdf['educ_professional_2019'])/tracts19gdf['educ_all_2019'])*100

tracts19gdf.head(10)
# Out:
#          GEOID                                           geometry  \
# 0  06037670403  POLYGON ((-13177840.910 3998757.250, -13177839...
# 1  06037670202  POLYGON ((-13177176.670 4000044.060, -13177164...
# 2  06037670701  POLYGON ((-13171166.080 3997280.030, -13171138...
# 3  06037293307  POLYGON ((-13170065.910 4000308.450, -13170065...
# 4  06037296300  POLYGON ((-13170120.120 3995289.290, -13170111...
# 5  06037297201  POLYGON ((-13168495.190 3991594.850, -13168494...
# 6  06037296600  POLYGON ((-13168733.750 3993416.960, -13168733...
# 7  06037297110  POLYGON ((-13167752.470 3992927.300, -13167751...
# 8  06037296220  POLYGON ((-13167749.020 3993777.050, -13167748...
# 9  06037294510  POLYGON ((-13166314.000 4000710.020, -13166192...
#
#    total_pop_2019  white_2019  black_2019  latx_2019  hh_total_2019  \
# 0          2733.0      1422.0        26.0      116.0         2733.0
# 1          2637.0      1473.0        25.0      481.0         2637.0
# 2          7185.0      3592.0        29.0     1841.0         7185.0
# 3          2284.0       259.0       183.0     1384.0         2284.0
# 4          5027.0      2082.0       458.0     1171.0         5027.0
# 5          4505.0       848.0       327.0     2892.0         4505.0
# 6          5358.0       795.0       313.0     4045.0         5358.0
# 7          4649.0       758.0       515.0     2988.0         4649.0
# 8          4447.0       412.0       568.0     2902.0         4447.0
# 9          5082.0        98.0        10.0     4958.0         5082.0
#
#    hh_female_head_2019  hh_kids_all_2019  hh_kids_yes_2019  ...  \
# 0                351.0             992.0             364.0  ...
# 1                397.0             889.0             319.0  ...
# 2               1101.0            2497.0             749.0  ...
# 3                431.0             914.0             223.0  ...
# 4               1030.0            2054.0             627.0  ...
# 5                645.0            1467.0             631.0  ...
# 6               1082.0            1948.0             564.0  ...
# 7                800.0            1558.0             501.0  ...
# 8               1018.0            1775.0             553.0  ...
# 9                451.0            1079.0             592.0  ...
#
#    part_black_2019  part_latx_2019  part_white_2019  part_female_head_2019  \
# 0         0.951336        4.244420        52.030735              12.843030
# 1         0.948047       18.240425        55.858931              15.054987
# 2         0.403619       25.622825        49.993041              15.323591
# 3         8.012259       60.595447        11.339755              18.870403
# 4         9.110802       23.294211        41.416352              20.489357
# 5         7.258602       64.195339        18.823529              14.317425
# 6         5.841732       75.494588        14.837626              20.194102
# 7        11.077651       64.271886        16.304582              17.208002
# 8        12.772656       65.257477         9.264673              22.891837
# 9         0.196773       97.560016         1.928375               8.874459
#
#    part_hh_kids_2019  part_rented_2019  part_unemployed_2019  \
# 0          36.693548         10.080645              5.409975
# 1          35.883015          4.836895              6.627018
# 2          29.995995         17.781338              3.392168
# 3          24.398249         76.258206              7.607901
# 4          30.525803         38.997079              9.097773
# 5          43.012952         79.141104              2.595745
# 6          28.952772         77.207392             13.636364
# 7          32.156611         84.916560              9.709544
# 8          31.154930         92.845070              5.607021
# 9          54.865616         64.782206              8.902334
#
#    part_poverty_2019  part_vacant_2019  part_college_2019
# 0           9.074277          2.840353           8.435583
# 1           1.980198          2.841530          11.755403
# 2           6.281337          0.636689          16.421896
# 3          38.266200          4.692388          29.645743
# 4          18.978248          0.000000          16.322089
# 5          15.278718          2.330226          31.940063
# 6          22.434815          8.026440          37.605593
# 7          55.642361          8.568075          34.054388
# 8          49.966269          7.407407          26.865136
# 9          37.544274          7.062877          36.567164
#
# [10 rows x 42 columns]

# %% [markdown]
# Beacuse cenpy does not offer a prepackaged ACS 14 prodcut, we used their remote api connection query framework to download the same data for LA County tracts for that year, to be joined via tract ID. Variables identified here https://api.census.gov/data/2014/acs/acs5/variables.html.

# %%
vars_to_download_14 = {
    "B25064_001E": "median_rent_2014",
    "B25077_001E": "median_value_2014",
    "B03002_001E": "total_pop_2014",
    "B03002_003E": "white_2014",
    "B03002_004E": "black_2014",
    "B03002_012E": "latx_2014",
    "B25003_001E": "housing_occupied_2014",
    "B25003_003E": "housing_rented_2014",
    "B09019_007E": "hh_female_head_2014",
    "B09019_001E": "hh_total_2014",
    "B15003_001E": "educ_all_2014",
    "B15003_015E": "educ_bachelors_2014",
    "B15003_016E": "educ_masters_2014",
    "B15003_017E": "educ_professional_2014",
    "B15003_018E": "educ_doctoral_2014", 
    "B19013_001E": "median_income_2014",
    "B23025_003E": "civ_laborforce_2014",
    "B23025_005E": "civ_unemployed_2014",
    "B17001_001E": "pov_all_2014",
    "B17001_002E": "pov_extreme_2014",
    "B17001_003E": "pov_severe_2014",
    "B17001_004E": "pov_in_2014",
    "B11005_001E": "hh_kids_all_2014",
    "B11005_002E": "hh_kids_yes_2014",
    "B25002_001E": "units_all_2014",
    "B25002_003E": "units_vacant_2014"
    
}
vars_to_download_l_14 = list(vars_to_download_14.keys())

# %%
alist=list(cenpy.explorer.available().index.unique())

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(alist)
# Out:
# ['ABSCB2017', 'ABSCB2018', 'ABSCBO2017', 'ABSCBO2018', 'ABSCS2017', 'ABSCS2018', 'ABSTCB2018', 'ACSCD1132011', 'ACSCD1152015', 'ACSCP1Y2010', 'ACSCP1Y2011', 'ACSCP1Y2012', 'ACSCP1Y2013', 'ACSCP1Y2014', 'ACSCP1Y2015', 'ACSCP1Y2016', 'ACSCP1Y2017', 'ACSCP1Y2018', 'ACSCP1Y2019', 'ACSCP3Y2012', 'ACSCP3Y2013', 'ACSCP5Y2015', 'ACSCP5Y2016', 'ACSCP5Y2017', 'ACSCP5Y2018', 'ACSCP5Y2019', 'ACSDP1Y2005', 'ACSDP1Y2006', 'ACSDP1Y2007', 'ACSDP1Y2008', 'ACSDP1Y2009', 'ACSDP1Y2010', 'ACSDP1Y2011', 'ACSDP1Y2012', 'ACSDP1Y2013', 'ACSDP1Y2014', 'ACSDP1Y2015', 'ACSDP1Y2016', 'ACSDP1Y2017', 'ACSDP1Y2018', 'ACSDP1Y2019', 'ACSDP3Y2007', 'ACSDP3Y2008', 'ACSDP3Y2009', 'ACSDP3Y2010', 'ACSDP3Y2011', 'ACSDP3Y2012', 'ACSDP3Y2013', 'ACSDP5Y2009', 'ACSDP5Y2010', 'ACSDP5Y2011', 'ACSDP5Y2012', 'ACSDP5Y2013', 'ACSDP5Y2014', 'ACSDP5Y2015', 'ACSDP5Y2016', 'ACSDP5Y2017', 'ACSDP5Y2018', 'ACSDP5Y2019', 'ACSDP5YAIAN2010', 'ACSDP5YAIAN2015', 'ACSDP5YSPT2010', 'ACSDT1Y2005', 'ACSDT1Y2006', 'ACSDT1Y2007', 'ACSDT1Y2008', 'ACSDT1Y2009', 'ACSDT1Y2010', 'ACSDT1Y2011', 'ACSDT1Y2012', 'ACSDT1Y2013', 'ACSDT1Y2014', 'ACSDT1Y2015', 'ACSDT1Y2016', 'ACSDT1Y2017', 'ACSDT1Y2018', 'ACSDT1Y2019', 'ACSDT3Y2007', 'ACSDT3Y2008', 'ACSDT3Y2009', 'ACSDT3Y2011', 'ACSDT3Y2012', 'ACSDT3Y2013', 'ACSDT5Y2009', 'ACSDT5Y2010', 'ACSDT5Y2011', 'ACSDT5Y2012', 'ACSDT5Y2013', 'ACSDT5Y2014', 'ACSDT5Y2015', 'ACSDT5Y2016', 'ACSDT5Y2017', 'ACSDT5Y2018', 'ACSDT5Y2019', 'ACSDT5YAIAN2010', 'ACSDT5YAIAN2015', 'ACSDT5YSPT2010', 'ACSDT5YSPT2015', 'ACSFLOWS2016', 'ACSFLOWS2017', 'ACSFLOWS2018', 'ACSFlows2010', 'ACSFlows2011', 'ACSFlows2012', 'ACSFlows2013', 'ACSFlows2014', 'ACSFlows2015', 'ACSLANG5Y2013', 'ACSSE2014', 'ACSSE2015', 'ACSSE2016', 'ACSSE2017', 'ACSSE2018', 'ACSSE2019', 'ACSSF5Y2009', 'ACSSPP1Y2008', 'ACSSPP1Y2009', 'ACSSPP1Y2010', 'ACSSPP1Y2011', 'ACSSPP1Y2012', 'ACSSPP1Y2013', 'ACSSPP1Y2014', 'ACSSPP1Y2015', 'ACSSPP1Y2016', 'ACSSPP1Y2017', 'ACSSPP1Y2018', 'ACSSPP1Y2019', 'ACSSPP3Y2009', 'ACSSPP3Y2010', 'ACSSPP3Y2011', 'ACSSPP3Y2012', 'ACSSPP3Y2013', 'ACSST1Y2010', 'ACSST1Y2011', 'ACSST1Y2012', 'ACSST1Y2013', 'ACSST1Y2014', 'ACSST1Y2015', 'ACSST1Y2016', 'ACSST1Y2017', 'ACSST1Y2018', 'ACSST1Y2019', 'ACSST3Y2010', 'ACSST3Y2011', 'ACSST3Y2012', 'ACSST3Y2013', 'ACSST5Y2010', 'ACSST5Y2011', 'ACSST5Y2012', 'ACSST5Y2013', 'ACSST5Y2014', 'ACSST5Y2015', 'ACSST5Y2016', 'ACSST5Y2017', 'ACSST5Y2018', 'ACSST5Y2019', 'ASECB2015', 'ASECB2016', 'ASECBO2015', 'ASECBO2016', 'ASECS2015', 'ASECS2016', 'ASECSA2014', 'ASECSCB2014', 'ASECSCBO2014', 'ASMAREA2012', 'ASMAREA2017', 'ASMBENCHMARK2017', 'ASMIndustry', 'ASMProduct', 'ASMState', 'ASMVALUE2012', 'ASMVALUE2017', 'BDSTIMESERIES', 'CBP1986', 'CBP1987', 'CBP1988', 'CBP1989', 'CBP1990', 'CBP1991', 'CBP1992', 'CBP1993', 'CBP1994', 'CBP1995', 'CBP1996', 'CBP1997', 'CBP1998', 'CBP1999', 'CBP2000', 'CBP2001', 'CBP2002', 'CBP2003', 'CBP2004', 'CBP2005', 'CBP2006', 'CBP2007', 'CBP2008', 'CBP2009', 'CBP2010', 'CBP2011', 'CBP2012', 'CBP2013', 'CBP2014', 'CBP2015', 'CBP2016', 'CBP2017', 'CBP2018', 'CBP2019', 'CFSAREA2012', 'CFSAREA2017', 'CFSEXPORT2012', 'CFSEXPORT2017', 'CFSHAZMAT2012', 'CFSHAZMAT2017', 'CFSPRELIM2012', 'CFSPRELIM2017', 'CFSTEMP2017', 'CPSPOVERTYTIMESERIES', 'DECENNIALAIAN2000', 'DECENNIALAIAN2010', 'DECENNIALAS2000', 'DECENNIALAS2010', 'DECENNIALCD110H', 'DECENNIALCD110S', 'DECENNIALCD1132010', 'DECENNIALCD1152010', 'DECENNIALCD1162010', 'DECENNIALCQR2000', 'DECENNIALDPAIAN2000', 'DECENNIALDPCD110H2000', 'DECENNIALDPCD110S2000', 'DECENNIALDPCD1132010', 'DECENNIALDPCD1152010', 'DECENNIALDPSF22000', 'DECENNIALDPSF32000', 'DECENNIALDPSF42000', 'DECENNIALDPSLDH2000', 'DECENNIALDPSLDS2000', 'DECENNIALGU2000', 'DECENNIALGU2010', 'DECENNIALMP2000', 'DECENNIALMP2010', 'DECENNIALPL2000', 'DECENNIALPL2010', 'DECENNIALPLNAT2010', 'DECENNIALRR2010', 'DECENNIALRR2020', 'DECENNIALSF12000', 'DECENNIALSF12010', 'DECENNIALSF22000', 'DECENNIALSF22010', 'DECENNIALSF32000', 'DECENNIALSF42000', 'DECENNIALSLDH', 'DECENNIALSLDS', 'DECENNIALVI2000', 'DECENNIALVI2010', 'DECENNIALYOEA ...

# %%
conn=cenpy.remote.APIConnection('ACSDT5Y2014')

# %%
tracts14df=cenpy.remote.APIConnection.query(conn,cols=vars_to_download_l_14, geo_unit='tract:*', geo_filter={'state':'06','county':'037'})

# %%
tracts14df.head()
# Out:
#   B25064_001E B25077_001E B03002_001E B03002_003E B03002_004E B03002_012E  \
# 0        1139      344400        3619        1306         101        1850
# 1         864      236200        4024        1309         203        1884
# 2        1222      348800        3878         293          79        3202
# 3        1250      353800        2759         130          93        2277
# 4        1547  -666666666        5208        1600         271        2241
#
#   B25003_001E B25003_003E B09019_007E B09019_001E  ... B17001_002E  \
# 0        1036         494         366        3619  ...         330
# 1        1208         544         490        4024  ...        1018
# 2         921         576         509        3878  ...        1105
# 3         708         581         246        2759  ...         477
# 4        2238        2231         865        5208  ...         630
#
#   B17001_003E B17001_004E B11005_001E B11005_002E B25002_001E B25002_003E  \
# 0         105           0        1036         256        1161         125
# 1         455         112        1208         544        1321         113
# 2         472          50         921         491         982          61
# 3         227          26         708         374         723          15
# 4         317          18        2238         599        2464         226
#
#   state county   tract
# 0    06    037  132501
# 1    06    037  132502
# 2    06    037  134001
# 3    06    037  134521
# 4    06    037  134903
#
# [5 rows x 29 columns]

# %%
tracts14df=tracts14df.rename(columns=vars_to_download_14)
tracts14df.head()
# Out:
#   median_rent_2014 median_value_2014 total_pop_2014 white_2014 black_2014  \
# 0             1139            344400           3619       1306        101
# 1              864            236200           4024       1309        203
# 2             1222            348800           3878        293         79
# 3             1250            353800           2759        130         93
# 4             1547        -666666666           5208       1600        271
#
#   latx_2014 housing_occupied_2014 housing_rented_2014 hh_female_head_2014  \
# 0      1850                  1036                 494                 366
# 1      1884                  1208                 544                 490
# 2      3202                   921                 576                 509
# 3      2277                   708                 581                 246
# 4      2241                  2238                2231                 865
#
#   hh_total_2014  ... pov_extreme_2014 pov_severe_2014 pov_in_2014  \
# 0          3619  ...              330             105           0
# 1          4024  ...             1018             455         112
# 2          3878  ...             1105             472          50
# 3          2759  ...              477             227          26
# 4          5208  ...              630             317          18
#
#   hh_kids_all_2014 hh_kids_yes_2014 units_all_2014 units_vacant_2014 state  \
# 0             1036              256           1161               125    06
# 1             1208              544           1321               113    06
# 2              921              491            982                61    06
# 3              708              374            723                15    06
# 4             2238              599           2464               226    06
#
#   county   tract
# 0    037  132501
# 1    037  132502
# 2    037  134001
# 3    037  134521
# 4    037  134903
#
# [5 rows x 29 columns]

# %%
tracts14df=tracts14df.astype(int)
tracts14df.dtypes
# Out:
# median_rent_2014          int64
# median_value_2014         int64
# total_pop_2014            int64
# white_2014                int64
# black_2014                int64
# latx_2014                 int64
# housing_occupied_2014     int64
# housing_rented_2014       int64
# hh_female_head_2014       int64
# hh_total_2014             int64
# educ_all_2014             int64
# educ_bachelors_2014       int64
# educ_masters_2014         int64
# educ_professional_2014    int64
# educ_doctoral_2014        int64
# median_income_2014        int64
# civ_laborforce_2014       int64
# civ_unemployed_2014       int64
# pov_all_2014              int64
# pov_extreme_2014          int64
# pov_severe_2014           int64
# pov_in_2014               int64
# hh_kids_all_2014          int64
# hh_kids_yes_2014          int64
# units_all_2014            int64
# units_vacant_2014         int64
# state                     int64
# county                    int64
# tract                     int64
# dtype: object

# %%
tracts14df.columns
# Out:
# Index(['median_rent_2014', 'median_value_2014', 'total_pop_2014', 'white_2014',
#        'black_2014', 'latx_2014', 'housing_occupied_2014',
#        'housing_rented_2014', 'hh_female_head_2014', 'hh_total_2014',
#        'educ_all_2014', 'educ_bachelors_2014', 'educ_masters_2014',
#        'educ_professional_2014', 'educ_doctoral_2014', 'median_income_2014',
#        'civ_laborforce_2014', 'civ_unemployed_2014', 'pov_all_2014',
#        'pov_extreme_2014', 'pov_severe_2014', 'pov_in_2014',
#        'hh_kids_all_2014', 'hh_kids_yes_2014', 'units_all_2014',
#        'units_vacant_2014', 'state', 'county', 'tract'],
#       dtype='object')

# %%
import numpy as np

# %%
columns14 = ['median_rent_2014', 'median_value_2014', 'total_pop_2014', 'white_2014',
       'black_2014', 'latx_2014', 'housing_occupied_2014',
       'housing_rented_2014', 'hh_female_head_2014', 'hh_total_2014',
       'educ_all_2014', 'educ_bachelors_2014', 'educ_masters_2014',
       'educ_professional_2014', 'educ_doctoral_2014', 'median_income_2014',
       'civ_laborforce_2014', 'civ_unemployed_2014', 'pov_all_2014',
       'pov_extreme_2014', 'pov_severe_2014', 'pov_in_2014',
       'hh_kids_all_2014', 'hh_kids_yes_2014', 'units_all_2014',
       'units_vacant_2014']
tracts14df[tracts14df[columns14] < 0]=np.nan

# %%
tracts14df.head(10)
# Out:
#    median_rent_2014  median_value_2014  total_pop_2014  white_2014  \
# 0            1139.0           344400.0            3619        1306
# 1             864.0           236200.0            4024        1309
# 2            1222.0           348800.0            3878         293
# 3            1250.0           353800.0            2759         130
# 4            1547.0                NaN            5208        1600
# 5            1063.0           366800.0            3938         750
# 6            2001.0           540800.0            3619        2354
# 7            2001.0           769600.0            2684        1885
# 8            1055.0           265400.0            3959         525
# 9            1882.0           492100.0            3356        2113
#
#    black_2014  latx_2014  housing_occupied_2014  housing_rented_2014  \
# 0         101       1850                   1036                  494
# 1         203       1884                   1208                  544
# 2          79       3202                    921                  576
# 3          93       2277                    708                  581
# 4         271       2241                   2238                 2231
# 5         109       2460                   1034                  522
# 6         186        410                   1283                  313
# 7         159        139                    946                   26
# 8          53       3102                   1268                  998
# 9         197        404                   1655                 1418
#
#    hh_female_head_2014  hh_total_2014  ...  pov_extreme_2014  pov_severe_2014  \
# 0                  366           3619  ...               330              105
# 1                  490           4024  ...              1018              455
# 2                  509           3878  ...              1105              472
# 3                  246           2759  ...               477              227
# 4                  865           5208  ...               630              317
# 5                  509           3938  ...               710              304
# 6                  700           3619  ...               241               84
# 7                  790           2684  ...                18                4
# 8                  591           3959  ...               931              505
# 9                  384           3356  ...               242                0
#
#    pov_in_2014  hh_kids_all_2014  hh_kids_yes_2014  units_all_2014  \
# 0            0              1036               256            1161
# 1          112              1208               544            1321
# 2           50               921               491             982
# 3           26               708               374             723
# 4           18              2238               599            2464
# 5           19              1034               497            1079
# 6            0              1283               466            1283
# 7            0               946               253             956
# 8            0              1268               643            1384
# 9            0              1655               229            1895
#
#    units_vacant_2014  state  county   tract
# 0                125      6      37  132501
# 1                113      6      37  132502
# 2                 61      6      37  134001
# 3                 15      6      37  134521
# 4                226      6      37  134903
# 5                 45      6      37  134002
# 6                  0      6      37  134423
# 7                 10      6      37  134424
# 8                116      6      37  134522
# 9                240      6      37  134905
#
# [10 rows x 29 columns]

# %%
tracts14df['part_black_2014']=(tracts14df['black_2014']/tracts14df['total_pop_2014'])*100
tracts14df['part_latx_2014']=(tracts14df['latx_2014']/tracts14df['total_pop_2014'])*100
tracts14df['part_white_2014']=(tracts14df['white_2014']/tracts14df['total_pop_2014'])*100
tracts14df['part_female_head_2014']=(tracts14df['hh_female_head_2014']/tracts14df['hh_total_2014'])*100
tracts14df['part_hh_kids_2014']=(tracts14df['hh_kids_yes_2014']/tracts14df['hh_kids_all_2014'])*100
tracts14df['part_rented_2014']=(tracts14df['housing_rented_2014']/tracts14df['housing_occupied_2014'])*100
tracts14df['part_unemployed_2014']=(tracts14df['civ_unemployed_2014']/tracts14df['civ_laborforce_2014'])*100
tracts14df['part_poverty_2014']=((tracts14df['pov_in_2014']+tracts14df['pov_severe_2014']+tracts14df['pov_extreme_2014'])/tracts14df['pov_all_2014'])*100
tracts14df['part_vacant_2014']=(tracts14df['units_vacant_2014']/tracts14df['units_all_2014'])*100
tracts14df['part_college_2014']=((tracts14df['educ_bachelors_2014']+tracts14df['educ_masters_2014']+tracts14df['educ_doctoral_2014']+tracts14df['educ_professional_2014'])/tracts14df['educ_all_2014'])*100

tracts14df.head(10)
# Out:
#    median_rent_2014  median_value_2014  total_pop_2014  white_2014  \
# 0            1139.0           344400.0            3619        1306
# 1             864.0           236200.0            4024        1309
# 2            1222.0           348800.0            3878         293
# 3            1250.0           353800.0            2759         130
# 4            1547.0                NaN            5208        1600
# 5            1063.0           366800.0            3938         750
# 6            2001.0           540800.0            3619        2354
# 7            2001.0           769600.0            2684        1885
# 8            1055.0           265400.0            3959         525
# 9            1882.0           492100.0            3356        2113
#
#    black_2014  latx_2014  housing_occupied_2014  housing_rented_2014  \
# 0         101       1850                   1036                  494
# 1         203       1884                   1208                  544
# 2          79       3202                    921                  576
# 3          93       2277                    708                  581
# 4         271       2241                   2238                 2231
# 5         109       2460                   1034                  522
# 6         186        410                   1283                  313
# 7         159        139                    946                   26
# 8          53       3102                   1268                  998
# 9         197        404                   1655                 1418
#
#    hh_female_head_2014  hh_total_2014  ...  part_black_2014  part_latx_2014  \
# 0                  366           3619  ...         2.790826       51.119094
# 1                  490           4024  ...         5.044732       46.819085
# 2                  509           3878  ...         2.037133       82.568334
# 3                  246           2759  ...         3.370787       82.529902
# 4                  865           5208  ...         5.203533       43.029954
# 5                  509           3938  ...         2.767902       62.468258
# 6                  700           3619  ...         5.139541       11.329096
# 7                  790           2684  ...         5.923994        5.178838
# 8                  591           3959  ...         1.338722       78.353119
# 9                  384           3356  ...         5.870083       12.038141
#
#    part_white_2014  part_female_head_2014  part_hh_kids_2014  \
# 0        36.087317              10.113291          24.710425
# 1        32.529821              12.176938          45.033113
# 2         7.555441              13.125322          53.311618
# 3         4.711852               8.916274          52.824859
# 4        30.721966              16.609063          26.764969
# 5        19.045201              12.925343          48.065764
# 6        65.045593              19.342360          36.321122
# 7        70.230999              29.433681          26.744186
# 8        13.260924              14.928012          50.709779
# 9        62.961859              11.442193          13.836858
#
#    part_rented_2014  part_unemployed_2014  part_poverty_2014  \
# 0         47.683398             10.094287          13.254113
# 1         45.033113             12.407992          40.341054
# 2         62.540717             11.151079          42.358761
# 3         82.062147              4.249668          26.838235
# 4         99.687221              9.272557          18.529186
# 5         50.483559              9.460738          26.325178
# 6         24.395947              7.393209           8.980381
# 7          2.748414              8.869908           0.819672
# 8         78.706625              8.423913          36.660710
# 9         85.679758              5.054590           7.210965
#
#    part_vacant_2014  part_college_2014
# 0         10.766581          31.852696
# 1          8.554126          32.906837
# 2          6.211813          28.835870
# 3          2.074689          33.018273
# 4          9.172078          28.972230
# 5          4.170528          35.323575
# 6          0.000000          20.176849
# 7          1.046025           6.989516
# 8          8.381503          35.262943
# 9         12.664908          13.120301
#
# [10 rows x 39 columns]

# %%
tracts19gdf['tract']=tracts19gdf['tract'].astype(int)
tracts19gdf.dtypes
# Out:
# GEOID                       object
# geometry                  geometry
# total_pop_2019             float64
# white_2019                 float64
# black_2019                 float64
# latx_2019                  float64
# hh_total_2019              float64
# hh_female_head_2019        float64
# hh_kids_all_2019           float64
# hh_kids_yes_2019           float64
# educ_all_2019              float64
# educ_bachelors_2019        float64
# educ_masters_2019          float64
# educ_professional_2019     float64
# educ_doctoral_2019         float64
# pov_all_2019               float64
# pov_extreme_2019           float64
# pov_severe_2019            float64
# pov_in_2019                float64
# median_income_2019         float64
# civ_laborforce_2019        float64
# civ_unemployed_2019        float64
# units_all_2019             float64
# units_vacant_2019          float64
# housing_occupied_2019      float64
# housing_rented_2019        float64
# median_rent_2019           float64
# median_value_2019          float64
# NAME                        object
# state                       object
# county                      object
# tract                        int64
# part_black_2019            float64
# part_latx_2019             float64
# part_white_2019            float64
# part_female_head_2019      float64
# part_hh_kids_2019          float64
# part_rented_2019           float64
# part_unemployed_2019       float64
# part_poverty_2019          float64
# part_vacant_2019           float64
# part_college_2019          float64
# dtype: object

# %%
tracts19gdf=tracts19gdf.set_index('tract')
tracts14df=tracts14df.set_index('tract')

joinedtractsgdf=tracts19gdf.join(tracts14df, on='tract', how='left', rsuffix='_14')

#joinedtractsgdf[joinedtractsgdf < 0]=np.nan

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(joinedtractsgdf.columns)
# Out:
# Index(['GEOID', 'geometry', 'total_pop_2019', 'white_2019', 'black_2019',
#        'latx_2019', 'hh_total_2019', 'hh_female_head_2019', 'hh_kids_all_2019',
#        'hh_kids_yes_2019', 'educ_all_2019', 'educ_bachelors_2019',
#        'educ_masters_2019', 'educ_professional_2019', 'educ_doctoral_2019',
#        'pov_all_2019', 'pov_extreme_2019', 'pov_severe_2019', 'pov_in_2019',
#        'median_income_2019', 'civ_laborforce_2019', 'civ_unemployed_2019',
#        'units_all_2019', 'units_vacant_2019', 'housing_occupied_2019',
#        'housing_rented_2019', 'median_rent_2019', 'median_value_2019', 'NAME',
#        'state', 'county', 'part_black_2019', 'part_latx_2019',
#        'part_white_2019', 'part_female_head_2019', 'part_hh_kids_2019',
#        'part_rented_2019', 'part_unemployed_2019', 'part_poverty_2019',
#        'part_vacant_2019', 'part_college_2019', 'median_rent_2014',
#        'median_value_2014', 'total_pop_2014', 'white_2014', 'black_2014',
#        'latx_2014', 'housing_occupied_2014', 'housing_rented_2014',
#        'hh_female_head_2014', 'hh_total_2014', 'educ_all_2014',
#        'educ_bachelors_2014', 'educ_masters_2014', 'educ_professional_2014',
#        'educ_doctoral_2014', 'median_income_2014', 'civ_laborforce_2014',
#        'civ_unemployed_2014', 'pov_all_2014', 'pov_extreme_2014',
#        'pov_severe_2014', 'pov_in_2014', 'hh_kids_all_2014',
#        'hh_kids_yes_2014', 'units_all_2014', 'units_vacant_2014', 'state_14',
#        'county_14', 'part_black_2014', 'part_latx_2014', 'part_white_2014',
#        'part_female_head_2014', 'part_hh_kids_2014', 'part_rented_2014',
#        'part_unemployed_2014', 'part_poverty_2014', 'part_vacant_2014',
#        'part_college_2014'],
#       dtype='object')

# %%
joinedtractsgdf=joinedtractsgdf.fillna(joinedtractsgdf.mean())

joinedtractsgdf.head(10)
# Out:
#               GEOID                                           geometry  \
# tract
# 670403  06037670403  POLYGON ((-13177840.910 3998757.250, -13177839...
# 670202  06037670202  POLYGON ((-13177176.670 4000044.060, -13177164...
# 670701  06037670701  POLYGON ((-13171166.080 3997280.030, -13171138...
# 293307  06037293307  POLYGON ((-13170065.910 4000308.450, -13170065...
# 296300  06037296300  POLYGON ((-13170120.120 3995289.290, -13170111...
# 297201  06037297201  POLYGON ((-13168495.190 3991594.850, -13168494...
# 296600  06037296600  POLYGON ((-13168733.750 3993416.960, -13168733...
# 297110  06037297110  POLYGON ((-13167752.470 3992927.300, -13167751...
# 296220  06037296220  POLYGON ((-13167749.020 3993777.050, -13167748...
# 294510  06037294510  POLYGON ((-13166314.000 4000710.020, -13166192...
#
#         total_pop_2019  white_2019  black_2019  latx_2019  hh_total_2019  \
# tract
# 670403          2733.0      1422.0        26.0      116.0         2733.0
# 670202          2637.0      1473.0        25.0      481.0         2637.0
# 670701          7185.0      3592.0        29.0     1841.0         7185.0
# 293307          2284.0       259.0       183.0     1384.0         2284.0
# 296300          5027.0      2082.0       458.0     1171.0         5027.0
# 297201          4505.0       848.0       327.0     2892.0         4505.0
# 296600          5358.0       795.0       313.0     4045.0         5358.0
# 297110          4649.0       758.0       515.0     2988.0         4649.0
# 296220          4447.0       412.0       568.0     2902.0         4447.0
# 294510          5082.0        98.0        10.0     4958.0         5082.0
#
#         hh_female_head_2019  hh_kids_all_2019  hh_kids_yes_2019  ...  \
# tract                                                            ...
# 670403                351.0             992.0             364.0  ...
# 670202                397.0             889.0             319.0  ...
# 670701               1101.0            2497.0             749.0  ...
# 293307                431.0             914.0             223.0  ...
# 296300               1030.0            2054.0             627.0  ...
# 297201                645.0            1467.0             631.0  ...
# 296600               1082.0            1948.0             564.0  ...
# 297110                800.0            1558.0             501.0  ...
# 296220               1018.0            1775.0             553.0  ...
# 294510                451.0            1079.0             592.0  ...
#
#         part_black_2014  part_latx_2014  part_white_2014  \
# tract
# 670403         0.759013        5.882353        55.749526
# 670202         1.371346        9.527246        65.716348
# 670701         2.423975       20.390774        52.563538
# 293307        16.425993       57.075812         8.086643
# 296300         1.018233       35.638172        44.541795
# 297201         8.874459       54.626623        27.191558
# 296600         6.502370       68.928910        17.175355
# 297110        15.839430       59.758750        15.701009
# 296220         8.841533       66.084788        13.148946
# 294510         0.021829       92.839991         6.701594
#
#         part_female_head_2014  part_hh_kids_2014  part_rented_2014  \
# tract
# 670403              26.831120          28.616025          8.636837
# 670202              25.802959          38.871473          6.269592
# 670701              22.858822          28.470864         17.911615
# 293307              13.176895          48.747153         74.943052
# 296300              17.049491          22.904707         38.289323
# 297201              13.311688          31.495468         62.084592
# 296600               9.649289          36.066424         77.893098
# 297110               8.206447          41.164921         88.874346
# 296220              10.383133          38.885330         89.301730
# 294510               9.626719          57.857858         56.256256
#
#         part_unemployed_2014  part_poverty_2014  part_vacant_2014  \
# tract
# 670403              6.222222           6.793169          4.945598
# 670202              1.821061           6.568026          1.441813
# 670701              6.531660           3.247612          2.627570
# 293307             16.426332          30.448950          7.578947
# 296300             11.124498          12.879507          6.645230
# 297201             14.755685          25.204806          9.439124
# 296600             12.327799          46.785850          5.400098
# 297110             20.034996          53.690476         10.381232
# 296220             23.291627          61.437316         12.695749
# 294510             15.179049          49.934354          7.500000
#
#         part_college_2014
# tract
# 670403          14.227435
# 670202          14.497192
# 670701          17.126527
# 293307          29.516995
# 296300          22.279961
# 297201          40.376390
# 296600          32.307223
# 297110          33.972515
# 296220          28.470196
# 294510          33.306836
#
# [10 rows x 79 columns]

# %%
joinedtractsgdf.dtypes
# Out:
# GEOID                     object
# geometry                geometry
# total_pop_2019           float64
# white_2019               float64
# black_2019               float64
#                           ...
# part_rented_2014         float64
# part_unemployed_2014     float64
# part_poverty_2014        float64
# part_vacant_2014         float64
# part_college_2014        float64
# Length: 79, dtype: object

# %%
joinedtractsgdf['change_rent_14_19']=joinedtractsgdf['median_rent_2019']-joinedtractsgdf['median_rent_2014']
joinedtractsgdf['change_value_14_19']=joinedtractsgdf['median_value_2019']-joinedtractsgdf['median_value_2014']
joinedtractsgdf['change_part_rented_14_19']=joinedtractsgdf['part_rented_2019']-joinedtractsgdf['part_rented_2014']
joinedtractsgdf['change_part_white_14_19']=joinedtractsgdf['part_white_2019']-joinedtractsgdf['part_white_2014']
joinedtractsgdf['change_part_black_14_19']=joinedtractsgdf['part_black_2019']-joinedtractsgdf['part_black_2014']
joinedtractsgdf['change_part_latx_14_19']=joinedtractsgdf['part_latx_2019']-joinedtractsgdf['part_latx_2014']
joinedtractsgdf['change_part_college_14_19']=joinedtractsgdf['part_college_2019']-joinedtractsgdf['part_college_2014']
joinedtractsgdf['change_part_unemployed_14_19']=joinedtractsgdf['part_unemployed_2019']-joinedtractsgdf['part_unemployed_2014']
joinedtractsgdf['change_part_hh_kids_14_19']=joinedtractsgdf['part_hh_kids_2019']-joinedtractsgdf['part_hh_kids_2014']
joinedtractsgdf['change_part_female_head_14_19']=joinedtractsgdf['part_female_head_2019']-joinedtractsgdf['part_female_head_2014']
joinedtractsgdf['change_part_poverty_14_19']=joinedtractsgdf['part_poverty_2019']-joinedtractsgdf['part_poverty_2014']
joinedtractsgdf['change_part_vacant_14_19']=joinedtractsgdf['part_vacant_2019']-joinedtractsgdf['part_vacant_2014']
joinedtractsgdf.head(10)
# Out:
#               GEOID                                           geometry  \
# tract
# 670403  06037670403  POLYGON ((-13177840.910 3998757.250, -13177839...
# 670202  06037670202  POLYGON ((-13177176.670 4000044.060, -13177164...
# 670701  06037670701  POLYGON ((-13171166.080 3997280.030, -13171138...
# 293307  06037293307  POLYGON ((-13170065.910 4000308.450, -13170065...
# 296300  06037296300  POLYGON ((-13170120.120 3995289.290, -13170111...
# 297201  06037297201  POLYGON ((-13168495.190 3991594.850, -13168494...
# 296600  06037296600  POLYGON ((-13168733.750 3993416.960, -13168733...
# 297110  06037297110  POLYGON ((-13167752.470 3992927.300, -13167751...
# 296220  06037296220  POLYGON ((-13167749.020 3993777.050, -13167748...
# 294510  06037294510  POLYGON ((-13166314.000 4000710.020, -13166192...
#
#         total_pop_2019  white_2019  black_2019  latx_2019  hh_total_2019  \
# tract
# 670403          2733.0      1422.0        26.0      116.0         2733.0
# 670202          2637.0      1473.0        25.0      481.0         2637.0
# 670701          7185.0      3592.0        29.0     1841.0         7185.0
# 293307          2284.0       259.0       183.0     1384.0         2284.0
# 296300          5027.0      2082.0       458.0     1171.0         5027.0
# 297201          4505.0       848.0       327.0     2892.0         4505.0
# 296600          5358.0       795.0       313.0     4045.0         5358.0
# 297110          4649.0       758.0       515.0     2988.0         4649.0
# 296220          4447.0       412.0       568.0     2902.0         4447.0
# 294510          5082.0        98.0        10.0     4958.0         5082.0
#
#         hh_female_head_2019  hh_kids_all_2019  hh_kids_yes_2019  ...  \
# tract                                                            ...
# 670403                351.0             992.0             364.0  ...
# 670202                397.0             889.0             319.0  ...
# 670701               1101.0            2497.0             749.0  ...
# 293307                431.0             914.0             223.0  ...
# 296300               1030.0            2054.0             627.0  ...
# 297201                645.0            1467.0             631.0  ...
# 296600               1082.0            1948.0             564.0  ...
# 297110                800.0            1558.0             501.0  ...
# 296220               1018.0            1775.0             553.0  ...
# 294510                451.0            1079.0             592.0  ...
#
#         change_part_rented_14_19  change_part_white_14_19  \
# tract
# 670403                  1.443809                -3.718790
# 670202                 -1.432697                -9.857417
# 670701                 -0.130278                -2.570496
# 293307                  1.315153                 3.253112
# 296300                  0.707756                -3.125443
# 297201                 17.056512                -8.368029
# 296600                 -0.685706                -2.337729
# 297110                 -3.957786                 0.603573
# 296220                  3.543341                -3.884273
# 294510                  8.525949                -4.773219
#
#         change_part_black_14_19  change_part_latx_14_19  \
# tract
# 670403                 0.192322               -1.637933
# 670202                -0.423299                8.713178
# 670701                -2.020357                5.232051
# 293307                -8.413734                3.519634
# 296300                 8.092568              -12.343961
# 297201                -1.615857                9.568715
# 296600                -0.660638                6.565678
# 297110                -4.761779                4.513136
# 296220                 3.931123               -0.827311
# 294510                 0.174944                4.720024
#
#         change_part_college_14_19  change_part_unemployed_14_19  \
# tract
# 670403                  -5.791852                     -0.812248
# 670202                  -2.741789                      4.805957
# 670701                  -0.704632                     -3.139492
# 293307                   0.128748                     -8.818432
# 296300                  -5.957872                     -2.026725
# 297201                  -8.436327                    -12.159940
# 296600                   5.298369                      1.308564
# 297110                   0.081873                    -10.325452
# 296220                  -1.605060                    -17.684606
# 294510                   3.260328                     -6.276715
#
#         change_part_hh_kids_14_19  change_part_female_head_14_19  \
# tract
# 670403                   8.077523                     -13.988090
# 670202                  -2.988459                     -10.747972
# 670701                   1.525131                      -7.535231
# 293307                 -24.348903                       5.693507
# 296300                   7.621096                       3.439867
# 297201                  11.517483                       1.005737
# 296600                  -7.113652                      10.544813
# 297110                  -9.008310                       9.001555
# 296220                  -7.730400                      12.508704
# 294510                  -2.992242                      -0.752260
#
#         change_part_poverty_14_19  change_part_vacant_14_19
# tract
# 670403                   2.281108                 -2.105246
# 670202                  -4.587828                  1.399717
# 670701                   3.033725                 -1.990881
# 293307                   7.817250                 -2.886559
# 296300                   6.098741                 -6.645230
# 297201                  -9.926088                 -7.108898
# 296600                 -24.351035                  2.626342
# 297110                   1.951885                 -1.813157
# 296220                 -11.471046                 -5.288342
# 294510                 -12.390081                 -0.437123
#
# [10 rows x 91 columns]

# %%
joinedtractsgdf=joinedtractsgdf.reset_index()
joinedtractsgdf.head(10)
# Out:
#     tract        GEOID                                           geometry  \
# 0  670403  06037670403  POLYGON ((-13177840.910 3998757.250, -13177839...
# 1  670202  06037670202  POLYGON ((-13177176.670 4000044.060, -13177164...
# 2  670701  06037670701  POLYGON ((-13171166.080 3997280.030, -13171138...
# 3  293307  06037293307  POLYGON ((-13170065.910 4000308.450, -13170065...
# 4  296300  06037296300  POLYGON ((-13170120.120 3995289.290, -13170111...
# 5  297201  06037297201  POLYGON ((-13168495.190 3991594.850, -13168494...
# 6  296600  06037296600  POLYGON ((-13168733.750 3993416.960, -13168733...
# 7  297110  06037297110  POLYGON ((-13167752.470 3992927.300, -13167751...
# 8  296220  06037296220  POLYGON ((-13167749.020 3993777.050, -13167748...
# 9  294510  06037294510  POLYGON ((-13166314.000 4000710.020, -13166192...
#
#    total_pop_2019  white_2019  black_2019  latx_2019  hh_total_2019  \
# 0          2733.0      1422.0        26.0      116.0         2733.0
# 1          2637.0      1473.0        25.0      481.0         2637.0
# 2          7185.0      3592.0        29.0     1841.0         7185.0
# 3          2284.0       259.0       183.0     1384.0         2284.0
# 4          5027.0      2082.0       458.0     1171.0         5027.0
# 5          4505.0       848.0       327.0     2892.0         4505.0
# 6          5358.0       795.0       313.0     4045.0         5358.0
# 7          4649.0       758.0       515.0     2988.0         4649.0
# 8          4447.0       412.0       568.0     2902.0         4447.0
# 9          5082.0        98.0        10.0     4958.0         5082.0
#
#    hh_female_head_2019  hh_kids_all_2019  ...  change_part_rented_14_19  \
# 0                351.0             992.0  ...                  1.443809
# 1                397.0             889.0  ...                 -1.432697
# 2               1101.0            2497.0  ...                 -0.130278
# 3                431.0             914.0  ...                  1.315153
# 4               1030.0            2054.0  ...                  0.707756
# 5                645.0            1467.0  ...                 17.056512
# 6               1082.0            1948.0  ...                 -0.685706
# 7                800.0            1558.0  ...                 -3.957786
# 8               1018.0            1775.0  ...                  3.543341
# 9                451.0            1079.0  ...                  8.525949
#
#    change_part_white_14_19  change_part_black_14_19  change_part_latx_14_19  \
# 0                -3.718790                 0.192322               -1.637933
# 1                -9.857417                -0.423299                8.713178
# 2                -2.570496                -2.020357                5.232051
# 3                 3.253112                -8.413734                3.519634
# 4                -3.125443                 8.092568              -12.343961
# 5                -8.368029                -1.615857                9.568715
# 6                -2.337729                -0.660638                6.565678
# 7                 0.603573                -4.761779                4.513136
# 8                -3.884273                 3.931123               -0.827311
# 9                -4.773219                 0.174944                4.720024
#
#    change_part_college_14_19  change_part_unemployed_14_19  \
# 0                  -5.791852                     -0.812248
# 1                  -2.741789                      4.805957
# 2                  -0.704632                     -3.139492
# 3                   0.128748                     -8.818432
# 4                  -5.957872                     -2.026725
# 5                  -8.436327                    -12.159940
# 6                   5.298369                      1.308564
# 7                   0.081873                    -10.325452
# 8                  -1.605060                    -17.684606
# 9                   3.260328                     -6.276715
#
#    change_part_hh_kids_14_19  change_part_female_head_14_19  \
# 0                   8.077523                     -13.988090
# 1                  -2.988459                     -10.747972
# 2                   1.525131                      -7.535231
# 3                 -24.348903                       5.693507
# 4                   7.621096                       3.439867
# 5                  11.517483                       1.005737
# 6                  -7.113652                      10.544813
# 7                  -9.008310                       9.001555
# 8                  -7.730400                      12.508704
# 9                  -2.992242                      -0.752260
#
#    change_part_poverty_14_19  change_part_vacant_14_19
# 0                   2.281108                 -2.105246
# 1                  -4.587828                  1.399717
# 2                   3.033725                 -1.990881
# 3                   7.817250                 -2.886559
# 4                   6.098741                 -6.645230
# 5                  -9.926088                 -7.108898
# 6                 -24.351035                  2.626342
# 7                   1.951885                 -1.813157
# 8                 -11.471046                 -5.288342
# 9                 -12.390081                 -0.437123
#
# [10 rows x 92 columns]

# %%
import matplotlib.pyplot as plt
import contextily as ctx

# %matplotlib inline

fig, ax=plt.subplots(figsize=(20,20))

joinedtractsgdf.plot(ax=ax, legend=True)

plt.title('LA Census Tracts')

ctx.add_basemap(ax,source=ctx.providers.Stamen.TonerLite,zoom=11)

ax.set_xticks([])
ax.set_yticks([])
# Out:
# []

# %% [markdown]
# Next, we will join the tract level information to the parcel scale, and generate the relevant proximity metrics.

# %%
parcelsgdf = gpd.GeoDataFrame(parcelsdf, geometry=gpd.points_from_xy(parcelsdf.center_lon, parcelsdf.center_lat))

# %%
parcelsgdf = parcelsgdf.set_crs("EPSG:4326")

parcelsgdf = parcelsgdf.to_crs("EPSG:3857")

print(parcelsgdf.crs)
# Out:
# EPSG:3857

# %%
#sparcelsgdf is Ellis-ed parcels (parcelsgdf) + [all parcels in LA + census data/demographic predictors (joinedtractsgdf)]
sparcelsgdf = gpd.sjoin(parcelsgdf, joinedtractsgdf, how="left", op='intersects',rsuffix="_tract")
sparcelsgdf.head()
# Out:
#    fid  center_lon  yearbuilt5  yearbuilt4  yearbuilt1      usetype  \
# 0    5 -118.434714         NaN         NaN      1961.0  Residential
# 1    7 -118.509913         NaN         NaN      1948.0  Residential
# 2    8 -118.434041         NaN         NaN      1981.0  Residential
# 3   21 -118.437185         NaN         NaN      1926.0  Residential
# 4   44 -118.511595         NaN         NaN      1952.0  Residential
#
#    yearbuilt2           apn  bedrooms1  bedrooms2  ...  \
# 0         NaN  4357-015-017          3          0  ...
# 1         NaN  2690-001-025          3          0  ...
# 2         NaN  4357-009-014          4          0  ...
# 3         NaN  4357-011-006          7          0  ...
# 4         NaN  2768-018-013          4          0  ...
#
#    change_part_rented_14_19  change_part_white_14_19  change_part_black_14_19  \
# 0                  2.589266                 7.468089                -0.707327
# 1                 -2.251442                -6.802456                 0.101599
# 2                  2.589266                 7.468089                -0.707327
# 3                  2.589266                 7.468089                -0.707327
# 4                 -2.251442                -6.802456                 0.101599
#
#   change_part_latx_14_19 change_part_college_14_19  \
# 0              -7.030906                 -0.307606
# 1              11.381757                 -2.240775
# 2              -7.030906                 -0.307606
# 3              -7.030906                 -0.307606
# 4              11.381757                 -2.240775
#
#    change_part_unemployed_14_19  change_part_hh_kids_14_19  \
# 0                     -1.943035                  10.173139
# 1                     -4.682100                  -4.108205
# 2                     -1.943035                  10.173139
# 3                     -1.943035                  10.173139
# 4                     -4.682100                  -4.108205
#
#    change_part_female_head_14_19  change_part_poverty_14_19  \
# 0                      -7.908945                   3.395515
# 1                      -7.347608                   3.197127
# 2                      -7.908945                   3.395515
# 3                      -7.908945                   3.395515
# 4                      -7.347608                   3.197127
#
#    change_part_vacant_14_19
# 0                  7.038295
# 1                  1.985045
# 2                  7.038295
# 3                  7.038295
# 4                  1.985045
#
# [5 rows x 150 columns]

# %%
sparcelsgdf.columns
# Out:
# Index(['fid', 'center_lon', 'yearbuilt5', 'yearbuilt4', 'yearbuilt1',
#        'usetype', 'yearbuilt2', 'apn', 'bedrooms1', 'bedrooms2',
#        ...
#        'change_part_rented_14_19', 'change_part_white_14_19',
#        'change_part_black_14_19', 'change_part_latx_14_19',
#        'change_part_college_14_19', 'change_part_unemployed_14_19',
#        'change_part_hh_kids_14_19', 'change_part_female_head_14_19',
#        'change_part_poverty_14_19', 'change_part_vacant_14_19'],
#       dtype='object', length=150)

# %%
fig, ax=plt.subplots(figsize=(20,20))

sparcelsgdf.plot(ax=ax, legend=True)

plt.title('LA Census Tracts')

ctx.add_basemap(ax,source=ctx.providers.Stamen.TonerLite,zoom=11)

ax.set_xticks([])
ax.set_yticks([])
# Out:
# []

# %%
sparcelsgdf['geometry']
#sparcels geometry is point data of parcels, not shape data of census tracts
# Out:
# 0         POINT (-13184092.001 4041657.430)
# 1         POINT (-13192463.204 4060449.266)
# 2         POINT (-13184017.140 4041788.250)
# 3         POINT (-13184367.137 4041401.590)
# 4         POINT (-13192650.436 4060140.606)
#                         ...
# 705229    POINT (-13156629.468 4040848.570)
# 705230    POINT (-13177522.620 4025225.777)
# 705231    POINT (-13176947.324 4024963.579)
# 705232    POINT (-13177522.620 4025225.777)
# 705233    POINT (-13176955.868 4024830.513)
# Name: geometry, Length: 705234, dtype: geometry

# %%
# Save sparcelsgdf to file
#sparcelsgdf.to_csv("sparcelsgdf.csv")

# %%
built_14_19gdf=gpd.GeoDataFrame(built_14_19df, geometry=gpd.points_from_xy(built_14_19df.center_lon, built_14_19df.center_lat))
sold_14_19gdf=gpd.GeoDataFrame(sold_14_19df, geometry=gpd.points_from_xy(sold_14_19df.center_lon, sold_14_19df.center_lat))

built_14_19gdf = built_14_19gdf.set_crs("EPSG:4326")
built_14_19gdf = built_14_19gdf.to_crs("EPSG:3857")

sold_14_19gdf = sold_14_19gdf.set_crs("EPSG:4326")
sold_14_19gdf = sold_14_19gdf.to_crs("EPSG:3857")

# %%
#built_14_19gdf.to_csv("built_14_19gdf.csv")
#sold_14_19gdf.to_csv("sold_14_19gdf.csv")

# %%
#sparcelsgdf1=sparcelsgdf[pd.isna(sparcelsgdf['hh_total_2019'])]
#print(len(sparcelsgdf1))

# %% [markdown]
# In order to identify proximity to high rent tracts and fast increasing rent tracts, we identified the 75th percentile value for 2019 rents and change of rents 2014-2019 to create new layers for a distance analysis.

# %%
#joinedtractsgdf['median_rent_2019'].describe()

# %%
#Antara, fill this value XXX with the 75% value
#highrenttractsgdf=joinedtractsgdf[joinedtractsgdf['median_rent_2019']>=XXX]

# %%
#joinedtractsgdf['change_rent_14_19'].describe()

# %%
#Antara, fill this value XXX with the 75% value
#highchangetractsgdf=joinedtractsgdf[sparcelsgdf['change_rent_14_19']>=]

# %% [markdown]
# ### Calculating percent of parcels bought and sold in each tract:

# %%
built_14_19gdf.head(5)
# Out:
#         fid  center_lon  yearbuilt5  yearbuilt4  yearbuilt1      usetype  \
# 354   28829 -118.173406         NaN         NaN      2016.0  Residential
# 1503  33479 -118.199631         NaN         NaN      2017.0  Residential
# 1759  34442 -118.199179         NaN         NaN      2017.0  Residential
# 1779  34529 -118.184365         NaN         NaN      2016.0  Residential
# 2078  36038 -118.197477         NaN         NaN      2015.0  Residential
#
#       yearbuilt2           apn  bedrooms1  bedrooms2  ...  bedrooms_total  \
# 354          NaN  5307-010-003          5          0  ...               5
# 1503         NaN  5209-003-011          5          0  ...               5
# 1759         NaN  5305-013-006          3          0  ...               3
# 1779         NaN  5301-012-025          4          0  ...               4
# 2078         NaN  5209-007-038          4          0  ...               4
#
#       bathrooms_total  sqft_total yearbuilt_avg built_to_land  \
# 354                 4        2527          2016      0.179037
# 1503                3        2176          2017      0.237265
# 1759                2        1282          2017      0.230104
# 1779                3        1961          2016      0.349691
# 2078                3        1915          2015      0.306273
#
#       estimated_density_per_acre  last_sold_date  sold_14_19  built_14_19  \
# 354                     3.086206      2008-09-09           0            1
# 1503                    4.749654      2017-11-08           1            1
# 1759                    7.818516      2013-11-05           0            1
# 1779                    7.767735      2016-09-26           1            1
# 2078                    6.966700      2016-10-07           1            1
#
#                                geometry
# 354   POINT (-13155003.402 4041098.226)
# 1503  POINT (-13157922.745 4039741.592)
# 1759  POINT (-13157872.368 4040087.257)
# 1779  POINT (-13156223.291 4042626.307)
# 2078  POINT (-13157682.987 4039748.564)
#
# [5 rows x 54 columns]

# %%
joinedtractsbuilt = gpd.sjoin(built_14_19gdf, joinedtractsgdf, how="left", op='intersects')
joinedtractsbuilt.head()
# Out:
#         fid  center_lon  yearbuilt5  yearbuilt4  yearbuilt1      usetype  \
# 354   28829 -118.173406         NaN         NaN      2016.0  Residential
# 1503  33479 -118.199631         NaN         NaN      2017.0  Residential
# 1759  34442 -118.199179         NaN         NaN      2017.0  Residential
# 1779  34529 -118.184365         NaN         NaN      2016.0  Residential
# 2078  36038 -118.197477         NaN         NaN      2015.0  Residential
#
#       yearbuilt2           apn  bedrooms1  bedrooms2  ...  \
# 354          NaN  5307-010-003          5          0  ...
# 1503         NaN  5209-003-011          5          0  ...
# 1759         NaN  5305-013-006          3          0  ...
# 1779         NaN  5301-012-025          4          0  ...
# 2078         NaN  5209-007-038          4          0  ...
#
#       change_part_rented_14_19  change_part_white_14_19  \
# 354                  -3.659969                 2.966994
# 1503                 -6.393546                -3.246582
# 1759                 -2.777957                 1.760069
# 1779                  5.713262                 2.179682
# 2078                 -6.393546                -3.246582
#
#       change_part_black_14_19 change_part_latx_14_19  \
# 354                  0.461657              -9.515362
# 1503                -2.303898               3.509699
# 1759                 0.868011              -7.776983
# 1779                 2.315482              -5.041721
# 2078                -2.303898               3.509699
#
#      change_part_college_14_19  change_part_unemployed_14_19  \
# 354                  -7.518334                     -9.773376
# 1503                 -5.381844                     -1.466173
# 1759                 -7.375104                     -4.459691
# 1779                  5.023246                     -2.101297
# 2078                 -5.381844                     -1.466173
#
#       change_part_hh_kids_14_19  change_part_female_head_14_19  \
# 354                  -18.699524                       5.478259
# 1503                   5.242700                       1.784626
# 1759                  -8.782604                      -0.003998
# 1779                  -6.852643                       3.858948
# 2078                   5.242700                       1.784626
#
#       change_part_poverty_14_19  change_part_vacant_14_19
# 354                    4.901542                  6.430797
# 1503                  -3.257410                 -2.135031
# 1759                 -17.699488                 -4.934777
# 1779                   1.136401                  3.470012
# 2078                  -3.257410                 -2.135031
#
# [5 rows x 146 columns]

# %%
joinedtractssold = gpd.sjoin(sold_14_19gdf, joinedtractsgdf, how="left", op='intersects')
joinedtractssold.head()
# Out:
#       fid  center_lon  yearbuilt5  yearbuilt4  yearbuilt1      usetype  \
# 2       8 -118.434041         NaN         NaN      1981.0  Residential
# 21  25489 -118.214994         NaN         NaN      1895.0  Residential
# 23  25512 -118.214505         NaN         NaN      1913.0  Residential
# 24  25519 -118.215087         NaN         NaN      1964.0  Residential
# 30  25721 -118.214634         NaN         NaN      1912.0   Commercial
#
#     yearbuilt2           apn  bedrooms1  bedrooms2  ...  \
# 2          NaN  4357-009-014          4          0  ...
# 21         NaN  5204-010-004          2          0  ...
# 23         NaN  5204-009-016          1          0  ...
# 24      1906.0  5204-009-023          1          2  ...
# 30         NaN  5204-011-001          0          0  ...
#
#     change_part_rented_14_19  change_part_white_14_19  \
# 2                   2.589266                 7.468089
# 21                 -4.680476                 0.497439
# 23                 -4.680476                 0.497439
# 24                 -4.680476                 0.497439
# 30                 -4.680476                 0.497439
#
#     change_part_black_14_19 change_part_latx_14_19 change_part_college_14_19  \
# 2                 -0.707327              -7.030906                 -0.307606
# 21                -0.022188               0.567481                 -0.606698
# 23                -0.022188               0.567481                 -0.606698
# 24                -0.022188               0.567481                 -0.606698
# 30                -0.022188               0.567481                 -0.606698
#
#     change_part_unemployed_14_19  change_part_hh_kids_14_19  \
# 2                      -1.943035                  10.173139
# 21                     -4.325974                   9.819669
# 23                     -4.325974                   9.819669
# 24                     -4.325974                   9.819669
# 30                     -4.325974                   9.819669
#
#     change_part_female_head_14_19  change_part_poverty_14_19  \
# 2                       -7.908945                   3.395515
# 21                      -2.371913                  -8.208570
# 23                      -2.371913                  -8.208570
# 24                      -2.371913                  -8.208570
# 30                      -2.371913                  -8.208570
#
#     change_part_vacant_14_19
# 2                   7.038295
# 21                  1.671086
# 23                  1.671086
# 24                  1.671086
# 30                  1.671086
#
# [5 rows x 145 columns]

# %%
built1419 = joinedtractsbuilt.groupby('tract')['built_14_19'].apply(lambda x: x[x == True].count())

# %%
sold1419 = joinedtractssold.groupby('tract')['sold_14_19'].apply(lambda x: x[x == True].count())

# %%
joinedtractsgdf = joinedtractsgdf.set_index('tract')
joinedtractsgdf
# Out:
#               GEOID                                           geometry  \
# tract
# 670403  06037670403  POLYGON ((-13177840.910 3998757.250, -13177839...
# 670202  06037670202  POLYGON ((-13177176.670 4000044.060, -13177164...
# 670701  06037670701  POLYGON ((-13171166.080 3997280.030, -13171138...
# 293307  06037293307  POLYGON ((-13170065.910 4000308.450, -13170065...
# 296300  06037296300  POLYGON ((-13170120.120 3995289.290, -13170111...
# ...             ...                                                ...
# 400404  06037400404  POLYGON ((-13118649.000 4052670.470, -13118599...
# 400403  06037400403  POLYGON ((-13114748.360 4045673.350, -13114745...
# 401603  06037401603  POLYGON ((-13111959.810 4043084.600, -13111939...
# 403318  06037403318  POLYGON ((-13111275.750 4033788.500, -13111272...
# 402703  06037402703  POLYGON ((-13106393.050 4039568.090, -13106391...
#
#         total_pop_2019  white_2019  black_2019  latx_2019  hh_total_2019  \
# tract
# 670403          2733.0      1422.0        26.0      116.0         2733.0
# 670202          2637.0      1473.0        25.0      481.0         2637.0
# 670701          7185.0      3592.0        29.0     1841.0         7185.0
# 293307          2284.0       259.0       183.0     1384.0         2284.0
# 296300          5027.0      2082.0       458.0     1171.0         5027.0
# ...                ...         ...         ...        ...            ...
# 400404          4268.0      2642.0         0.0      821.0         4268.0
# 400403          3906.0      1960.0        71.0     1375.0         3906.0
# 401603          2951.0      1579.0       122.0     1053.0         2951.0
# 403318          6367.0      1484.0       533.0     1951.0         6367.0
# 402703          4661.0       563.0       502.0     3120.0         4661.0
#
#         hh_female_head_2019  hh_kids_all_2019  hh_kids_yes_2019  ...  \
# tract                                                            ...
# 670403                351.0             992.0             364.0  ...
# 670202                397.0             889.0             319.0  ...
# 670701               1101.0            2497.0             749.0  ...
# 293307                431.0             914.0             223.0  ...
# 296300               1030.0            2054.0             627.0  ...
# ...                     ...               ...               ...  ...
# 400404                614.0            1403.0             428.0  ...
# 400403                631.0            1292.0             367.0  ...
# 401603                706.0            1300.0             234.0  ...
# 403318                943.0            1928.0             780.0  ...
# 402703                620.0            1281.0             594.0  ...
#
#         change_part_rented_14_19  change_part_white_14_19  \
# tract
# 670403                  1.443809                -3.718790
# 670202                 -1.432697                -9.857417
# 670701                 -0.130278                -2.570496
# 293307                  1.315153                 3.253112
# 296300                  0.707756                -3.125443
# ...                          ...                      ...
# 400404                 -2.185690               -17.431568
# 400403                 -6.476404                 1.614676
# 401603                 -0.607874               -14.004154
# 403318                  7.237443                 2.195289
# 402703                 -1.055257                 2.087349
#
#         change_part_black_14_19  change_part_latx_14_19  \
# tract
# 670403                 0.192322               -1.637933
# 670202                -0.423299                8.713178
# 670701                -2.020357                5.232051
# 293307                -8.413734                3.519634
# 296300                 8.092568              -12.343961
# ...                         ...                     ...
# 400404                -2.135476                8.880263
# 400403                -6.047181                4.924810
# 401603                 2.761436               12.099574
# 403318                -4.480447               -0.228121
# 402703                -3.230619               -2.016235
#
#         change_part_college_14_19  change_part_unemployed_14_19  \
# tract
# 670403                  -5.791852                     -0.812248
# 670202                  -2.741789                      4.805957
# 670701                  -0.704632                     -3.139492
# 293307                   0.128748                     -8.818432
# 296300                  -5.957872                     -2.026725
# ...                           ...                           ...
# 400404                   2.372952                     -0.506049
# 400403                 -10.196791                     -2.162224
# 401603                  -7.040308                     -7.758675
# 403318                  -0.183311                     -2.162675
# 402703                  -0.082156                    -10.178243
#
#         change_part_hh_kids_14_19  change_part_female_head_14_19  \
# tract
# 670403                   8.077523                     -13.988090
# 670202                  -2.988459                     -10.747972
# 670701                   1.525131                      -7.535231
# 293307                 -24.348903                       5.693507
# 296300                   7.621096                       3.439867
# ...                           ...                            ...
# 400404                  -7.200035                      -9.471506
# 400403                  -5.563354                      -4.617381
# 401603                  -1.696970                       5.057497
# 403318                   1.930556                      -5.034576
# 402703                  -2.242189                      -0.761945
#
#         change_part_poverty_14_19  change_part_vacant_14_19
# tract
# 670403                   2.281108                 -2.105246
# 670202                  -4.587828                  1.399717
# 670701                   3.033725                 -1.990881
# 293307                   7.817250                 -2.886559
# 296300                   6.098741                 -6.645230
# ...                           ...                       ...
# 400404                   5.782051                 -0.985215
# 400403                   6.632169                  0.648644
# 401603                  -9.579609                 -5.838286
# 403318                   7.296800                 -3.572114
# 402703                  -6.205228                 -4.860688
#
# [2346 rows x 91 columns]

# %%
aggDf = pd.DataFrame({'n_built1419': built1419, 'n_sold1419': sold1419})

# %%
joinedbuiltsold = pd.merge(joinedtractsgdf,aggDf, how='left', on='tract')
joinedbuiltsold
# Out:
#               GEOID                                           geometry  \
# tract
# 670403  06037670403  POLYGON ((-13177840.910 3998757.250, -13177839...
# 670202  06037670202  POLYGON ((-13177176.670 4000044.060, -13177164...
# 670701  06037670701  POLYGON ((-13171166.080 3997280.030, -13171138...
# 293307  06037293307  POLYGON ((-13170065.910 4000308.450, -13170065...
# 296300  06037296300  POLYGON ((-13170120.120 3995289.290, -13170111...
# ...             ...                                                ...
# 400404  06037400404  POLYGON ((-13118649.000 4052670.470, -13118599...
# 400403  06037400403  POLYGON ((-13114748.360 4045673.350, -13114745...
# 401603  06037401603  POLYGON ((-13111959.810 4043084.600, -13111939...
# 403318  06037403318  POLYGON ((-13111275.750 4033788.500, -13111272...
# 402703  06037402703  POLYGON ((-13106393.050 4039568.090, -13106391...
#
#         total_pop_2019  white_2019  black_2019  latx_2019  hh_total_2019  \
# tract
# 670403          2733.0      1422.0        26.0      116.0         2733.0
# 670202          2637.0      1473.0        25.0      481.0         2637.0
# 670701          7185.0      3592.0        29.0     1841.0         7185.0
# 293307          2284.0       259.0       183.0     1384.0         2284.0
# 296300          5027.0      2082.0       458.0     1171.0         5027.0
# ...                ...         ...         ...        ...            ...
# 400404          4268.0      2642.0         0.0      821.0         4268.0
# 400403          3906.0      1960.0        71.0     1375.0         3906.0
# 401603          2951.0      1579.0       122.0     1053.0         2951.0
# 403318          6367.0      1484.0       533.0     1951.0         6367.0
# 402703          4661.0       563.0       502.0     3120.0         4661.0
#
#         hh_female_head_2019  hh_kids_all_2019  hh_kids_yes_2019  ...  \
# tract                                                            ...
# 670403                351.0             992.0             364.0  ...
# 670202                397.0             889.0             319.0  ...
# 670701               1101.0            2497.0             749.0  ...
# 293307                431.0             914.0             223.0  ...
# 296300               1030.0            2054.0             627.0  ...
# ...                     ...               ...               ...  ...
# 400404                614.0            1403.0             428.0  ...
# 400403                631.0            1292.0             367.0  ...
# 401603                706.0            1300.0             234.0  ...
# 403318                943.0            1928.0             780.0  ...
# 402703                620.0            1281.0             594.0  ...
#
#         change_part_black_14_19  change_part_latx_14_19  \
# tract
# 670403                 0.192322               -1.637933
# 670202                -0.423299                8.713178
# 670701                -2.020357                5.232051
# 293307                -8.413734                3.519634
# 296300                 8.092568              -12.343961
# ...                         ...                     ...
# 400404                -2.135476                8.880263
# 400403                -6.047181                4.924810
# 401603                 2.761436               12.099574
# 403318                -4.480447               -0.228121
# 402703                -3.230619               -2.016235
#
#         change_part_college_14_19  change_part_unemployed_14_19  \
# tract
# 670403                  -5.791852                     -0.812248
# 670202                  -2.741789                      4.805957
# 670701                  -0.704632                     -3.139492
# 293307                   0.128748                     -8.818432
# 296300                  -5.957872                     -2.026725
# ...                           ...                           ...
# 400404                   2.372952                     -0.506049
# 400403                 -10.196791                     -2.162224
# 401603                  -7.040308                     -7.758675
# 403318                  -0.183311                     -2.162675
# 402703                  -0.082156                    -10.178243
#
#         change_part_hh_kids_14_19  change_part_female_head_14_19  \
# tract
# 670403                   8.077523                     -13.988090
# 670202                  -2.988459                     -10.747972
# 670701                   1.525131                      -7.535231
# 293307                 -24.348903                       5.693507
# 296300                   7.621096                       3.439867
# ...                           ...                            ...
# 400404                  -7.200035                      -9.471506
# 400403                  -5.563354                      -4.617381
# 401603                  -1.696970                       5.057497
# 403318                   1.930556                      -5.034576
# 402703                  -2.242189                      -0.761945
#
#         change_part_poverty_14_19  change_part_vacant_14_19  n_built1419  \
# tract
# 670403                   2.281108                 -2.105246          NaN
# 670202                  -4.587828                  1.399717          NaN
# 670701                   3.033725                 -1.990881          NaN
# 293307                   7.817250                 -2.886559          NaN
# 296300                   6.098741                 -6.645230         44.0
# ...                           ...                       ...          ...
# 400404                   5.782051                 -0.985215          NaN
# 400403                   6.632169                  0.648644          NaN
# 401603                  -9.579609                 -5.838286          NaN
# 403318                   7.296800                 -3.572114          NaN
# 402703                  -6.205228                 -4.860688          NaN
#
#         n_sold1419
# tract
# 670403         NaN
# 670202         NaN
# 670701         6.0
# 293307        93.0
# 296300       474.0
# ...            ...
# 400404         NaN
# 400403         NaN
# 401603         NaN
# 403318         NaN
# 402703         NaN
#
# [2346 rows x 93 columns]

# %%
totalparcels = sparcelsgdf.groupby('tract').size()
totalparcels
# Out:
# tract
# 101110    1221
# 101122    1328
# 101210     741
# 101220     762
# 101300    1537
#           ...
# 980023       3
# 980024      75
# 980026      12
# 980028       8
# 980031       1
# Length: 1000, dtype: int64

# %%
joinedbuiltsold['totalparcels'] = totalparcels
joinedbuiltsold.head(5)
# Out:
#               GEOID                                           geometry  \
# tract
# 670403  06037670403  POLYGON ((-13177840.910 3998757.250, -13177839...
# 670202  06037670202  POLYGON ((-13177176.670 4000044.060, -13177164...
# 670701  06037670701  POLYGON ((-13171166.080 3997280.030, -13171138...
# 293307  06037293307  POLYGON ((-13170065.910 4000308.450, -13170065...
# 296300  06037296300  POLYGON ((-13170120.120 3995289.290, -13170111...
#
#         total_pop_2019  white_2019  black_2019  latx_2019  hh_total_2019  \
# tract
# 670403          2733.0      1422.0        26.0      116.0         2733.0
# 670202          2637.0      1473.0        25.0      481.0         2637.0
# 670701          7185.0      3592.0        29.0     1841.0         7185.0
# 293307          2284.0       259.0       183.0     1384.0         2284.0
# 296300          5027.0      2082.0       458.0     1171.0         5027.0
#
#         hh_female_head_2019  hh_kids_all_2019  hh_kids_yes_2019  ...  \
# tract                                                            ...
# 670403                351.0             992.0             364.0  ...
# 670202                397.0             889.0             319.0  ...
# 670701               1101.0            2497.0             749.0  ...
# 293307                431.0             914.0             223.0  ...
# 296300               1030.0            2054.0             627.0  ...
#
#         change_part_latx_14_19  change_part_college_14_19  \
# tract
# 670403               -1.637933                  -5.791852
# 670202                8.713178                  -2.741789
# 670701                5.232051                  -0.704632
# 293307                3.519634                   0.128748
# 296300              -12.343961                  -5.957872
#
#         change_part_unemployed_14_19  change_part_hh_kids_14_19  \
# tract
# 670403                     -0.812248                   8.077523
# 670202                      4.805957                  -2.988459
# 670701                     -3.139492                   1.525131
# 293307                     -8.818432                 -24.348903
# 296300                     -2.026725                   7.621096
#
#         change_part_female_head_14_19  change_part_poverty_14_19  \
# tract
# 670403                     -13.988090                   2.281108
# 670202                     -10.747972                  -4.587828
# 670701                      -7.535231                   3.033725
# 293307                       5.693507                   7.817250
# 296300                       3.439867                   6.098741
#
#         change_part_vacant_14_19  n_built1419  n_sold1419  totalparcels
# tract
# 670403                 -2.105246          NaN         NaN           NaN
# 670202                  1.399717          NaN         NaN           NaN
# 670701                 -1.990881          NaN         6.0          23.0
# 293307                 -2.886559          NaN        93.0         412.0
# 296300                 -6.645230         44.0       474.0        1515.0
#
# [5 rows x 94 columns]

# %%
joinedbuiltsold['pctbuilt'] = joinedbuiltsold['n_built1419']/joinedbuiltsold['totalparcels']*100
joinedbuiltsold['pctsold'] = joinedbuiltsold['n_sold1419']/joinedbuiltsold['totalparcels']*100
joinedbuiltsold.head(5)
# Out:
#               GEOID                                           geometry  \
# tract
# 670403  06037670403  POLYGON ((-13177840.910 3998757.250, -13177839...
# 670202  06037670202  POLYGON ((-13177176.670 4000044.060, -13177164...
# 670701  06037670701  POLYGON ((-13171166.080 3997280.030, -13171138...
# 293307  06037293307  POLYGON ((-13170065.910 4000308.450, -13170065...
# 296300  06037296300  POLYGON ((-13170120.120 3995289.290, -13170111...
#
#         total_pop_2019  white_2019  black_2019  latx_2019  hh_total_2019  \
# tract
# 670403          2733.0      1422.0        26.0      116.0         2733.0
# 670202          2637.0      1473.0        25.0      481.0         2637.0
# 670701          7185.0      3592.0        29.0     1841.0         7185.0
# 293307          2284.0       259.0       183.0     1384.0         2284.0
# 296300          5027.0      2082.0       458.0     1171.0         5027.0
#
#         hh_female_head_2019  hh_kids_all_2019  hh_kids_yes_2019  ...  \
# tract                                                            ...
# 670403                351.0             992.0             364.0  ...
# 670202                397.0             889.0             319.0  ...
# 670701               1101.0            2497.0             749.0  ...
# 293307                431.0             914.0             223.0  ...
# 296300               1030.0            2054.0             627.0  ...
#
#         change_part_unemployed_14_19  change_part_hh_kids_14_19  \
# tract
# 670403                     -0.812248                   8.077523
# 670202                      4.805957                  -2.988459
# 670701                     -3.139492                   1.525131
# 293307                     -8.818432                 -24.348903
# 296300                     -2.026725                   7.621096
#
#         change_part_female_head_14_19  change_part_poverty_14_19  \
# tract
# 670403                     -13.988090                   2.281108
# 670202                     -10.747972                  -4.587828
# 670701                      -7.535231                   3.033725
# 293307                       5.693507                   7.817250
# 296300                       3.439867                   6.098741
#
#         change_part_vacant_14_19  n_built1419  n_sold1419  totalparcels  \
# tract
# 670403                 -2.105246          NaN         NaN           NaN
# 670202                  1.399717          NaN         NaN           NaN
# 670701                 -1.990881          NaN         6.0          23.0
# 293307                 -2.886559          NaN        93.0         412.0
# 296300                 -6.645230         44.0       474.0        1515.0
#
#         pctbuilt    pctsold
# tract
# 670403       NaN        NaN
# 670202       NaN        NaN
# 670701       NaN  26.086957
# 293307       NaN  22.572816
# 296300   2.90429  31.287129
#
# [5 rows x 96 columns]

# %%
joinedbuiltsold = joinedbuiltsold.fillna(0)
joinedbuiltsold.head(5)
# Out:
#               GEOID                                           geometry  \
# tract
# 670403  06037670403  POLYGON ((-13177840.910 3998757.250, -13177839...
# 670202  06037670202  POLYGON ((-13177176.670 4000044.060, -13177164...
# 670701  06037670701  POLYGON ((-13171166.080 3997280.030, -13171138...
# 293307  06037293307  POLYGON ((-13170065.910 4000308.450, -13170065...
# 296300  06037296300  POLYGON ((-13170120.120 3995289.290, -13170111...
#
#         total_pop_2019  white_2019  black_2019  latx_2019  hh_total_2019  \
# tract
# 670403          2733.0      1422.0        26.0      116.0         2733.0
# 670202          2637.0      1473.0        25.0      481.0         2637.0
# 670701          7185.0      3592.0        29.0     1841.0         7185.0
# 293307          2284.0       259.0       183.0     1384.0         2284.0
# 296300          5027.0      2082.0       458.0     1171.0         5027.0
#
#         hh_female_head_2019  hh_kids_all_2019  hh_kids_yes_2019  ...  \
# tract                                                            ...
# 670403                351.0             992.0             364.0  ...
# 670202                397.0             889.0             319.0  ...
# 670701               1101.0            2497.0             749.0  ...
# 293307                431.0             914.0             223.0  ...
# 296300               1030.0            2054.0             627.0  ...
#
#         change_part_unemployed_14_19  change_part_hh_kids_14_19  \
# tract
# 670403                     -0.812248                   8.077523
# 670202                      4.805957                  -2.988459
# 670701                     -3.139492                   1.525131
# 293307                     -8.818432                 -24.348903
# 296300                     -2.026725                   7.621096
#
#         change_part_female_head_14_19  change_part_poverty_14_19  \
# tract
# 670403                     -13.988090                   2.281108
# 670202                     -10.747972                  -4.587828
# 670701                      -7.535231                   3.033725
# 293307                       5.693507                   7.817250
# 296300                       3.439867                   6.098741
#
#         change_part_vacant_14_19  n_built1419  n_sold1419  totalparcels  \
# tract
# 670403                 -2.105246          0.0         0.0           0.0
# 670202                  1.399717          0.0         0.0           0.0
# 670701                 -1.990881          0.0         6.0          23.0
# 293307                 -2.886559          0.0        93.0         412.0
# 296300                 -6.645230         44.0       474.0        1515.0
#
#         pctbuilt    pctsold
# tract
# 670403   0.00000   0.000000
# 670202   0.00000   0.000000
# 670701   0.00000  26.086957
# 293307   0.00000  22.572816
# 296300   2.90429  31.287129
#
# [5 rows x 96 columns]

# %%
sparcelsgdf.set_index('ain', inplace=True)

# %%
sparcelsgdf['ain']
# Out:
# 0         4357015017
# 1         2690001025
# 2         4357009014
# 3         4357011006
# 4         2768018013
#              ...
# 705229    5302027008
# 705230    4103009044
# 705231    4103015007
# 705232    4103009043
# 705233    4103015014
# Name: ain, Length: 705234, dtype: int64

# %%
highrenttractsgdf=joinedtractsgdf[joinedtractsgdf['median_rent_2019']>=1821.750000]

def get_closest_tract(row):
    parcel = row.geometry
    distances = highrenttractsgdf.distance(parcel)
    min_dist = distances.min()
    return pd.Series([min_dist])

sparcelsgdf[['dist_to_nearest_highrenttract']] = sparcelsgdf.apply(get_closest_tract, axis=1)
sparcelsgdf.head()
# Out:
#             fid  center_lon  yearbuilt5  yearbuilt4  yearbuilt1      usetype  \
# ain
# 4357015017    5 -118.434714         NaN         NaN      1961.0  Residential
# 2690001025    7 -118.509913         NaN         NaN      1948.0  Residential
# 4357009014    8 -118.434041         NaN         NaN      1981.0  Residential
# 4357011006   21 -118.437185         NaN         NaN      1926.0  Residential
# 2768018013   44 -118.511595         NaN         NaN      1952.0  Residential
#
#             yearbuilt2           apn  bedrooms1  bedrooms2  ...  \
# ain                                                         ...
# 4357015017         NaN  4357-015-017          3          0  ...
# 2690001025         NaN  2690-001-025          3          0  ...
# 4357009014         NaN  4357-009-014          4          0  ...
# 4357011006         NaN  4357-011-006          7          0  ...
# 2768018013         NaN  2768-018-013          4          0  ...
#
#             change_part_white_14_19  change_part_black_14_19  \
# ain
# 4357015017                 7.468089                -0.707327
# 2690001025                -6.802456                 0.101599
# 4357009014                 7.468089                -0.707327
# 4357011006                 7.468089                -0.707327
# 2768018013                -6.802456                 0.101599
#
#             change_part_latx_14_19 change_part_college_14_19  \
# ain
# 4357015017               -7.030906                 -0.307606
# 2690001025               11.381757                 -2.240775
# 4357009014               -7.030906                 -0.307606
# 4357011006               -7.030906                 -0.307606
# 2768018013               11.381757                 -2.240775
#
#            change_part_unemployed_14_19  change_part_hh_kids_14_19  \
# ain
# 4357015017                    -1.943035                  10.173139
# 2690001025                    -4.682100                  -4.108205
# 4357009014                    -1.943035                  10.173139
# 4357011006                    -1.943035                  10.173139
# 2768018013                    -4.682100                  -4.108205
#
#             change_part_female_head_14_19  change_part_poverty_14_19  \
# ain
# 4357015017                      -7.908945                   3.395515
# 2690001025                      -7.347608                   3.197127
# 4357009014                      -7.908945                   3.395515
# 4357011006                      -7.908945                   3.395515
# 2768018013                      -7.347608                   3.197127
#
#             change_part_vacant_14_19  dist_to_nearest_highrenttract
# ain
# 4357015017                  7.038295                     507.232099
# 2690001025                  1.985045                    1535.197835
# 4357009014                  7.038295                     399.916938
# 4357011006                  7.038295                     259.478126
# 2768018013                  1.985045                    1621.702540
#
# [5 rows x 150 columns]

# %%
highrenttractsgdf.head(5)
# Out:
#               GEOID                                           geometry  \
# tract
# 670403  06037670403  POLYGON ((-13177840.910 3998757.250, -13177839...
# 670202  06037670202  POLYGON ((-13177176.670 4000044.060, -13177164...
# 670701  06037670701  POLYGON ((-13171166.080 3997280.030, -13171138...
# 296300  06037296300  POLYGON ((-13170120.120 3995289.290, -13170111...
# 980031  06037980031  POLYGON ((-13168099.230 3995788.280, -13168038...
#
#         total_pop_2019  white_2019  black_2019  latx_2019  hh_total_2019  \
# tract
# 670403          2733.0      1422.0        26.0      116.0         2733.0
# 670202          2637.0      1473.0        25.0      481.0         2637.0
# 670701          7185.0      3592.0        29.0     1841.0         7185.0
# 296300          5027.0      2082.0       458.0     1171.0         5027.0
# 980031          1175.0       393.0       232.0      387.0         1175.0
#
#         hh_female_head_2019  hh_kids_all_2019  hh_kids_yes_2019  ...  \
# tract                                                            ...
# 670403                351.0             992.0             364.0  ...
# 670202                397.0             889.0             319.0  ...
# 670701               1101.0            2497.0             749.0  ...
# 296300               1030.0            2054.0             627.0  ...
# 980031                 19.0              24.0              19.0  ...
#
#         change_part_black_14_19  change_part_latx_14_19  \
# tract
# 670403                 0.192322               -1.637933
# 670202                -0.423299                8.713178
# 670701                -2.020357                5.232051
# 296300                 8.092568              -12.343961
# 980031                -4.624251                1.188597
#
#         change_part_college_14_19  change_part_unemployed_14_19  \
# tract
# 670403                  -5.791852                     -0.812248
# 670202                  -2.741789                      4.805957
# 670701                  -0.704632                     -3.139492
# 296300                  -5.957872                     -2.026725
# 980031                  14.360802                      0.000000
#
#         change_part_hh_kids_14_19  change_part_female_head_14_19  \
# tract
# 670403                   8.077523                     -13.988090
# 670202                  -2.988459                     -10.747972
# 670701                   1.525131                      -7.535231
# 296300                   7.621096                       3.439867
# 980031                 -20.833333                       0.451973
#
#         change_part_poverty_14_19  change_part_vacant_14_19  \
# tract
# 670403                   2.281108                 -2.105246
# 670202                  -4.587828                  1.399717
# 670701                   3.033725                 -1.990881
# 296300                   6.098741                 -6.645230
# 980031                   0.000000                  0.000000
#
#         nearest_highrenttract  dist_to_nearest_highrenttract
# tract
# 670403               670403.0                            0.0
# 670202               670202.0                            0.0
# 670701               670701.0                            0.0
# 296300               296300.0                            0.0
# 980031               980031.0                            0.0
#
# [5 rows x 93 columns]

# %%
sparcelsgdf.head(5)
# Out:
#    fid  center_lon  yearbuilt5  yearbuilt4  yearbuilt1      usetype  \
# 0    5 -118.434714         NaN         NaN      1961.0  Residential
# 1    7 -118.509913         NaN         NaN      1948.0  Residential
# 2    8 -118.434041         NaN         NaN      1981.0  Residential
# 3   21 -118.437185         NaN         NaN      1926.0  Residential
# 4   44 -118.511595         NaN         NaN      1952.0  Residential
#
#    yearbuilt2           apn  bedrooms1  bedrooms2  ...  \
# 0         NaN  4357-015-017          3          0  ...
# 1         NaN  2690-001-025          3          0  ...
# 2         NaN  4357-009-014          4          0  ...
# 3         NaN  4357-011-006          7          0  ...
# 4         NaN  2768-018-013          4          0  ...
#
#    change_part_rented_14_19  change_part_white_14_19  change_part_black_14_19  \
# 0                  2.589266                 7.468089                -0.707327
# 1                 -2.251442                -6.802456                 0.101599
# 2                  2.589266                 7.468089                -0.707327
# 3                  2.589266                 7.468089                -0.707327
# 4                 -2.251442                -6.802456                 0.101599
#
#   change_part_latx_14_19 change_part_college_14_19  \
# 0              -7.030906                 -0.307606
# 1              11.381757                 -2.240775
# 2              -7.030906                 -0.307606
# 3              -7.030906                 -0.307606
# 4              11.381757                 -2.240775
#
#    change_part_unemployed_14_19  change_part_hh_kids_14_19  \
# 0                     -1.943035                  10.173139
# 1                     -4.682100                  -4.108205
# 2                     -1.943035                  10.173139
# 3                     -1.943035                  10.173139
# 4                     -4.682100                  -4.108205
#
#    change_part_female_head_14_19  change_part_poverty_14_19  \
# 0                      -7.908945                   3.395515
# 1                      -7.347608                   3.197127
# 2                      -7.908945                   3.395515
# 3                      -7.908945                   3.395515
# 4                      -7.347608                   3.197127
#
#    change_part_vacant_14_19
# 0                  7.038295
# 1                  1.985045
# 2                  7.038295
# 3                  7.038295
# 4                  1.985045
#
# [5 rows x 150 columns]

# %% [markdown]
# Now we want to create our datasets for the statistical and clustering tests, one of ellis properties with the parcel information joined, and another of all parcels, with an indication of the ellis status.

# %%
studyellisdf.dtypes

# %%
studyellisdf=studyellisdf.set_index('ain')
sparcelgsdf=sparcelsgdf.set_index('ain')

parcelsjoindf=sparcelsgdf.join(studyellisdf, on='ain', how='left', rsuffix='_ellis')

parcelsjoindf.head()

# %%
parcelsjoindf1=parcelsjoindf[pd.isna(parcelsjoindf['units_withdrawn'])]
print(len(parcelsjoindf1))

# %%
parcelsjoindf2=parcelsjoindf[pd.notna(parcelsjoindf['units_withdrawn'])]
print(len(parcelsjoindf2))

# %%
parcelsjoindf3=parcelsjoindf[parcelsjoindf['units_total']>1]

parcelsjoindf4=parcelsjoindf3[parcelsjoindf3['yearbuilt_avg']<1979]

print(len(parcelsjoindf4))

# %%
parcelsjoindf5=parcelsjoindf4[pd.notna(parcelsjoindf4['units_withdrawn'])]

print(len(parcelsjoindf5))

# %%
ellisjoindf = studyellisdf.join(parcelsdf, on='ain', how='left', rsuffix='parcel')

ellisjoindf.head()

# %% [markdown]
# With our Ellis datset, we will also want to create a new field that takes the difference between the filing date and the last sale date for the property. Thereby we can filter out negative diffs (landlord no longer owns property) and study the difference in neighborhood conditions in changing filing times.

# %%
ellisjoindf['time_to_file']=ellisjoindf['application_date']-ellisjoindf['last_sold_date']
ellisjoindf['time_to_file']=ellisjoindf['time_to_file'].astype('timedelta64[D]')

# %%
ellisjoindf.head()

# %%
ellisjoindf.dtypes

# %% [markdown]
# Now we'll want to check and see to waht extent parcels have been built since an Ellis Filing, and to what extent they have been sold since the filing, which will determine whether or not the record can remain in the sample.

# %%
ellisjoindf.yearbuilt_avg.unique()

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(ellisjoindf.time_to_file.value_counts())

# %%
print(len(ellisjoindf))

# %%
ellisjoindf1=ellisjoindf[ellisjoindf['time_to_file']>-1]
print(len(ellisjoindf1))

# %%
ellisjoindf2=ellisjoindf1[ellisjoindf1['landlord_type']>0]
print(len(ellisjoindf2))
